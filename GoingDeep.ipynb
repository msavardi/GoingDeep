# %% [markdown]
# # Brewing Logistic Regression then Going Deeper
#
# While Caffe is made for deep networks it can likewise represent "shallow" models like logistic regression for classification. We'll do simple logistic regression on synthetic data that we'll generate and save to HDF5 to feed vectors to Caffe. Once that model is done, we'll add layers to improve accuracy. That's what Caffe is about: define a model, experiment, and then deploy.

# %% [markdown]
# ### 1. Setup
#
# * Python usual setup with `numpy`, and `matplotlib`.

# %%
import numpy as np
import matplotlib.pyplot as plt
# display the plot inline in this notebook
# %matplotlib inline

# %% [markdown]
# * Load `caffe`.

# %%
# The caffe module needs to be on the Python path;
#  we'll add it here explicitly.
import os
os.chdir('..')
import sys
caffe_root = '/home/NAME/caffe/'  # this file should be run from {caffe_root}/examples (otherwise change this line)
sys.path.insert(0, caffe_root + 'python')

import caffe # If you get "No module named _caffe", either you have not built pycaffe or you have the wrong path.

# %% [markdown]
# * Load additional useful lib.

# %%
import h5py
import shutil
import tempfile

import sklearn
import sklearn.datasets
import sklearn.linear_model

import pandas as pd

# Visualize net
from google.protobuf import text_format
from caffe.draw import get_pydot_graph
from caffe.proto import caffe_pb2
from IPython.display import display, Image 


sklearn.__version__
# Out:
# '0.14.1'

# %% [markdown]
# ### 2. Load the dataset
#
# We load the dataset used in the previous lab *Data scientist for a day*

# %%
 train_data = pd.read_csv('DeepLearning/train.csv', header=None)
 train_labels = pd.read_csv('DeepLearning/trainLabels.csv', header=None)
 test_data = pd.read_csv('DeepLearning/test.csv', header=None)
 X = np.asarray(train_data)
 y = np.asarray(train_labels).ravel()
 X_test= np.asarray(test_data)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# %% [markdown]
# Data enters Caffe through data layers: they lie at the bottom of nets. Data can come from efficient databases (LevelDB or LMDB), directly from memory, or, when efficiency is not critical, from files on disk in HDF5 or common image formats.
# HDF5 is a Hierarchical Data Format consisting of a data format specification and a supporting library implementation.
#
# Next we save the dataset to HDF5 for loading in Caffe.

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./DeepLearning/hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')
submission_filename = os.path.join(dirname, 'submission.h5')


# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')
    
with h5py.File(submission_filename, 'w') as f:
    f.create_dataset('data', data=X_test, **comp_kwargs)
with open(os.path.join(dirname, 'submission.txt'), 'w') as f:
    f.write(submission_filename + '\n')

# %% [markdown]
# ### 3. Simple logistic regressor
#
# Let's define logistic regression in Caffe through Python net specification.
#
# ![Test](logistic.png "Test")
#
# This is a quick and natural way to define nets that sidesteps manually editing the protobuf model. A network is a set of layers and their connections. Caffe creates and checks the net from the definition.
# Data and derivatives flow through the net as blobs that is an array interface
#
# Blobs are N-D arrays for storing and communicating information.
# * hold data, derivatives, and parameters
# * lazily allocate memory
# * shuttle between CPU and GPU

# %%
from caffe import layers as L
from caffe import params as P

def logreg(hdf5, batch_size):
    # logistic regression: data, matrix multiplication, and 2-class softmax loss
    n = caffe.NetSpec()
    n.data, n.label = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=2)
    n.ip1 = L.InnerProduct(n.data, num_output=2, weight_filler=dict(type='xavier'))
    n.accuracy = L.Accuracy(n.ip1, n.label)
    n.loss = L.SoftmaxWithLoss(n.ip1, n.label)
    return n.to_proto()

train_net_path = 'DeepLearning/hdf5_classification/logreg_auto_train.prototxt'
with open(train_net_path, 'w') as f:
    f.write(str(logreg('DeepLearning/hdf5_classification/data/train.txt', 10)))

test_net_path = 'DeepLearning/hdf5_classification/logreg_auto_test.prototxt'
with open(test_net_path, 'w') as f:
    f.write(str(logreg('DeepLearning/hdf5_classification/data/test.txt', 10)))

# %% [markdown]
# * Let's visualize the network graph

# %%
def view_graph(prototxt):
    _net = caffe_pb2.NetParameter()
    f = open(prototxt)
    text_format.Merge(f.read(), _net)
    display(Image(get_pydot_graph(_net,"TB").create_png()))
    
view_graph("DeepLearning/hdf5_classification/logreg_auto_test.prototxt")

# %% [markdown]
# ___
# * Do you notice any differences respect the previous graph?
# * What's the meaning of the "2" above ip1 node?
# * Where are the `blobs`?
# ___

# %% [markdown]
# #### Define the solver
# Now, we'll define our "solver" which trains the network by specifying the locations of the train and test nets we defined above, as well as setting values for various parameters used for learning, display, and "snapshotting".

# %%
from caffe.proto import caffe_pb2

class create_solver(object):
    def __init__(self, train_net_path, test_net_path):
        self.train_net_path = train_net_path
        self.test_net_path = test_net_path
        
        self.define_solver()
    
    def define_solver(self):
        self.s = caffe_pb2.SolverParameter()

        # Specify locations of the train and test networks.
        self.s.train_net = self.train_net_path
        self.s.test_net.append(self.test_net_path)

        self.s.test_interval = 100  # Test after every 100 training iterations.
        self.s.test_iter.append(250) # Test 250 "batches" each time we test.

        self.s.max_iter = 10000      # # of times to update the net (training iterations)

        # Set the initial learning rate for stochastic gradient descent (SGD).
        self.s.base_lr = 0.1        
        # Set `lr_policy` to define how the learning rate changes during training.
        # Here, we 'step' the learning rate by multiplying it by a factor `gamma`
        # every `stepsize` iterations.
        self.s.lr_policy = 'step'
        self.s.gamma = 0.1
        self.s.stepsize = 5000

        # Set other optimization parameters. Setting a non-zero `momentum` takes a
        # weighted average of the current gradient and previous gradients to make
        # learning more stable. L2 weight decay regularizes learning, to help prevent
        # the model from overfitting.
        self.s.momentum = 0.9
        self.s.weight_decay = 5e-4

        # Display the current training loss and accuracy every 1000 iterations.
        self.s.display = 100

        # Snapshots are files used to store networks we've trained.  Here, we'll
        # snapshot every 10K iterations -- just once at the end of training.
        # For larger networks that take longer to train, you may want to set
        # snapshot < max_iter to save the network and training state to disk during
        # optimization, preventing disaster in case of machine crashes, etc.
        self.s.snapshot = 10000
        self.s.snapshot_prefix = 'DeepLearning/hdf5_classification/data/train'

        # We'll train on the CPU for fair benchmarking against scikit-learn.
        # Changing to GPU should result in much faster training!
        self.s.solver_mode = caffe_pb2.SolverParameter.CPU

        return self.s

    def write_solver(self, solver_path):
        with open(solver_path, 'w') as f:
            f.write(str(self.s))
        
solver_path = 'DeepLearning/hdf5_classification/logreg_solver.prototxt'
s = create_solver(train_net_path, test_net_path)       
s.write_solver(solver_path)

# %% [markdown]
# Time to learn and evaluate our Caffeinated logistic regression in Python.

# %%
#%%timeit
caffe.set_mode_cpu()
solver = caffe.get_solver(solver_path)
solver.solve()

accuracy = 0
batch_size = solver.test_nets[0].blobs['data'].num
test_iters = int(len(Xt) / batch_size)
for i in range(test_iters):
    solver.test_nets[0].forward()
    accuracy += solver.test_nets[0].blobs['accuracy'].data
accuracy /= test_iters

print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 0.776

# %% [markdown]
# ### Visualization
# It's very simple to access to the weight, parameters, and intermediate results that are attached to a network graph.

# %%
# weights connecting the input with ip1
arr = solver.net.params["ip1"][0].data

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
cax = ax.matshow(arr, interpolation='none')
fig.colorbar(cax, orientation="horizontal")

# %%
_ = plt.hist(arr.tolist(), bins=10)

# %% [markdown]
# ### Best parameters
# Now try to hack the code above in order to find the best parameters (remember the previous lab, and how perform a grid search). I'm shure you could reach at least an accuracy of: `0.876`

# %%
# Hint: edit the parameters by directly access the create_solver class data structure 
s = create_solver(train_net_path, test_net_path)       
s.s.base_lr = 0.1                      # change the learning rate
s.write_solver(solver_path)            # recreate the solver prototxt


[...]
# Out:
#   File "<ipython-input-12-398f64c7bb08>", line 7
#     [...]
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# * What is the impact of `learning rate` and `weight decay` regularization?

# %% [markdown]
# You could always do the same through the command line interface, for detailed output on the model and solving. Remember to correctly change the path according to your directories tree

# %%
# !/home/met/caffe-nv/build/tools/caffe train -solver DeepLearning/hdf5_classification/logreg_solver.prototxt

# %% [markdown]
# ### 4. Non linearity
#
# If you look at output or the `logreg_auto_train.prototxt`, you'll see that the model is simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer network.
# That network is given in `nonlinear_auto_train.prototxt`, and that's the only change made in `nonlinear_logreg_solver.prototxt` which we will now use.
#
# The final accuracy of the new network should be higher than logistic regression!

# %%
from caffe import layers as L
from caffe import params as P

def nonlinear_net(hdf5, batch_size, dim):
    # one small nonlinearity, one leap for model kind
    n = caffe.NetSpec()
    n.data, n.label = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=2)
    # define a hidden layer of dimension 40
    n.ip1 = L.InnerProduct(n.data, num_output=dim, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu1 = L.ReLU(n.ip1, in_place=True)
    # score the (now non-linear) features
    n.ip2 = L.InnerProduct(n.ip1, num_output=2, weight_filler=dict(type='xavier'))
    # same accuracy and loss as before
    n.accuracy = L.Accuracy(n.ip2, n.label)
    n.loss = L.SoftmaxWithLoss(n.ip2, n.label)
    return n.to_proto()

def predict_net(hdf5, batch_size,dim):
    # one small nonlinearity, one leap for model kind
    n = caffe.NetSpec()
    n.data = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=1)
    # define a hidden layer of dimension 40
    n.ip1 = L.InnerProduct(n.data, num_output=dim, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu1 = L.ReLU(n.ip1, in_place=True)
    # score the (now non-linear) features
    n.ip2 = L.InnerProduct(n.ip1, num_output=2, weight_filler=dict(type='xavier'))
    # same accuracy and loss as before
    return n.to_proto()

train_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_train.prototxt'
with open(train_net_path, 'w') as f:
    f.write(str(nonlinear_net('DeepLearning/hdf5_classification/data/train.txt', 10, 40)))

test_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_test.prototxt'
with open(test_net_path, 'w') as f:
    f.write(str(nonlinear_net('DeepLearning/hdf5_classification/data/test.txt', 10, 40)))
    
submission_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_submission.prototxt'
with open(submission_net_path, 'w') as f:
    f.write(str(predict_net('DeepLearning/hdf5_classification/data/submission.txt', 10, 40)))

solver_path = 'DeepLearning/hdf5_classification/nonlinear_logreg_solver.prototxt'
s = create_solver(train_net_path, test_net_path)
s.s.base_lr = 0.01
s.write_solver(solver_path)

# %% [markdown]
# Visualize the network graph.

# %%
view_graph("DeepLearning/hdf5_classification/nonlinear_auto_test.prototxt")

# %%
# It's your turn
# Try to improve your score!

[...]

#>>> LR: 0.1, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.908
# Out:
#   File "<ipython-input-1-8bf9d9e15dce>", line 4
#     [...]
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# * Find the best parameters!
# * Can you breake the wall of `0.9` of accuracy?

# %% [markdown]
# ### 5. Let's go deeper
#
# Try to pack many layers in order to increase your model capacity. But pay attention that, the more you increase your model's capacity, the more you could overfit your training data!
# Look carefully at the image below:
# ![Capacity](capacity.png "Capacity")

# %% [markdown]
# * Have you got the point? Now try to create a model with an optimal capacity according to you data.

# %%
from caffe import layers as L
from caffe import params as P


def nonlinear_net(hdf5, batch_size):
    # one small nonlinearity, one leap for model kind
    n = caffe.NetSpec()
    n.data, n.label = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=2)
    # define a hidden layer of dimension 40
    n.ip1 = L.InnerProduct(n.data, num_output=20, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu1 = L.ReLU(n.ip1, in_place=True)
    
    # define a hidden layer of dimension 40
    n.ip2 = L.InnerProduct(n.ip1, num_output=20, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu2 = L.ReLU(n.ip2, in_place=True)
    # define a hidden layer of dimension 40
    n.ip3 = L.InnerProduct(n.ip2, num_output=10, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu3 = L.ReLU(n.ip3, in_place=True)
    drop = L.Dropout(n.ip3, in_place=True)
    
    # define a hidden layer of dimension 40
    n.ip4 = L.InnerProduct(drop, num_output=5, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu4 = L.ReLU(n.ip4, in_place=True)
    
    # score the (now non-linear) features
    n.ip5 = L.InnerProduct(n.ip4, num_output=2, weight_filler=dict(type='xavier'))
    # same accuracy and loss as before
    n.accuracy = L.Accuracy(n.ip4, n.label)
    n.loss = L.SoftmaxWithLoss(n.ip4, n.label)
    return n.to_proto()

def predict_net(hdf5, batch_size):
    # one small nonlinearity, one leap for model kind
    n = caffe.NetSpec()
    n.data = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=1)
    # define a hidden layer of dimension 40
    n.ip1 = L.InnerProduct(n.data, num_output=20, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu1 = L.ReLU(n.ip1, in_place=True)
    
    # define a hidden layer of dimension 40
    n.ip2 = L.InnerProduct(n.ip1, num_output=20, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu2 = L.ReLU(n.ip2, in_place=True)
    # define a hidden layer of dimension 40
    n.ip3 = L.InnerProduct(n.ip2, num_output=10, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu3 = L.ReLU(n.ip3, in_place=True)
    # define a hidden layer of dimension 40
    n.ip4 = L.InnerProduct(n.ip3, num_output=5, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu4 = L.ReLU(n.ip4, in_place=True)
    
    # score the (now non-linear) features
    n.ip5 = L.InnerProduct(n.ip4, num_output=2, weight_filler=dict(type='xavier'))
    # same accuracy and loss as before
    return n.to_proto()

train_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_train.prototxt'
with open(train_net_path, 'w') as f:
    f.write(str(nonlinear_net('DeepLearning/hdf5_classification/data/train.txt', 10)))

test_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_test.prototxt'
with open(test_net_path, 'w') as f:
    f.write(str(nonlinear_net('DeepLearning/hdf5_classification/data/test.txt', 10)))
    
submission_net_path = 'DeepLearning/hdf5_classification/nonlinear_auto_submission.prototxt'
with open(submission_net_path, 'w') as f:
    f.write(str(predict_net('DeepLearning/hdf5_classification/data/submission.txt', 10)))

solver_path = 'DeepLearning/hdf5_classification/nonlinear_logreg_solver.prototxt'
s = create_solver(train_net_path, test_net_path)
s.s.base_lr = 0.01
s.write_solver(solver_path)

# %%
# %%timeit
caffe.set_mode_cpu()
solver = caffe.get_solver(solver_path)
solver.solve()

accuracy = 0
batch_size = solver.test_nets[0].blobs['data'].num
test_iters = int(len(Xt) / batch_size)
for i in range(test_iters):
    solver.test_nets[0].forward()
    accuracy += solver.test_nets[0].blobs['accuracy'].data
accuracy /= test_iters

print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 0.876
# Accuracy: 0.864
# Accuracy: 0.884
# Accuracy: 0.876
# 1 loop, best of 3: 496 ms per loop

# %%
#%%timeit

best = 0
for lr in [0.1, 0.05, 0.01, 0.005, 0.001]:
    for momentum in [0.5, 0.7, 0.9]:
        for weight in [5e-1,5e-2,5e-3,5e-4,5e-5,5e-6]:
            caffe.set_mode_cpu()

            s = create_solver(train_net_path, test_net_path)
            s.s.base_lr = lr      
            #s.s.gamma = gamma
            #s.s.stepsize = step
            s.s.momentum = momentum
            s.s.weight_decay = weight
            s.write_solver(solver_path)

            acc = 0
            for i in xrange(4):
                caffe.set_mode_cpu()
                solver = caffe.get_solver(solver_path)
                solver.solve()
                
                accuracy = 0
                batch_size = solver.test_nets[0].blobs['data'].num
                test_iters = int(len(Xt) / batch_size)
                for i in range(test_iters):
                    solver.test_nets[0].forward()
                    accuracy += solver.test_nets[0].blobs['accuracy'].data
                accuracy /= test_iters
                acc += accuracy/4 
            if acc > best:
                add = ">>>"
                best = acc
            else:
                add = ""
            print("{} LR: {}, Momentum: {}, Weight: {}, Accuracy: {:.3f}".format(add, lr, momentum, weight, accuracy)) 
print("Done!")
# Out:
# >>> LR: 0.1, Momentum: 0.5, Weight: 0.5, Accuracy: 0.520
# >>> LR: 0.1, Momentum: 0.5, Weight: 0.05, Accuracy: 0.892
# >>> LR: 0.1, Momentum: 0.5, Weight: 0.005, Accuracy: 0.888
#  LR: 0.1, Momentum: 0.5, Weight: 0.0005, Accuracy: 0.828
#  LR: 0.1, Momentum: 0.5, Weight: 5e-05, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.5, Weight: 5e-06, Accuracy: 0.844
#  LR: 0.1, Momentum: 0.7, Weight: 0.5, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.7, Weight: 0.05, Accuracy: 0.884
#  LR: 0.1, Momentum: 0.7, Weight: 0.005, Accuracy: 0.876
#  LR: 0.1, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.7, Weight: 5e-05, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.7, Weight: 5e-06, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.9, Weight: 0.5, Accuracy: 0.480
#  LR: 0.1, Momentum: 0.9, Weight: 0.05, Accuracy: 0.480
#  LR: 0.1, Momentum: 0.9, Weight: 0.005, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.9, Weight: 0.0005, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.9, Weight: 5e-05, Accuracy: 0.520
#  LR: 0.1, Momentum: 0.9, Weight: 5e-06, Accuracy: 0.520
#  LR: 0.05, Momentum: 0.5, Weight: 0.5, Accuracy: 0.520
#  LR: 0.05, Momentum: 0.5, Weight: 0.05, Accuracy: 0.876
#  LR: 0.05, Momentum: 0.5, Weight: 0.005, Accuracy: 0.864
#  LR: 0.05, Momentum: 0.5, Weight: 0.0005, Accuracy: 0.872
#  LR: 0.05, Momentum: 0.5, Weight: 5e-05, Accuracy: 0.872
#  LR: 0.05, Momentum: 0.5, Weight: 5e-06, Accuracy: 0.864
#  LR: 0.05, Momentum: 0.7, Weight: 0.5, Accuracy: 0.520
#  LR: 0.05, Momentum: 0.7, Weight: 0.05, Accuracy: 0.860
#  LR: 0.05, Momentum: 0.7, Weight: 0.005, Accuracy: 0.868
#  LR: 0.05, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.880
#  LR: 0.05, Momentum: 0.7, Weight: 5e-05, Accuracy: 0.892
#  LR: 0.05, Momentum: 0.7, Weight: 5e-06, Accuracy: 0.880
#  LR: 0.05, Momentum: 0.9, Weight: 0.5, Accuracy: 0.520
#  LR: 0.05, Momentum: 0.9, Weight: 0.05, Accuracy: 0.520
#  LR: 0.05, Momentum: 0.9, Weight: 0.005, Accuracy: 0.852
#  LR: 0.05, Momentum: 0.9, Weight: 0.0005, Accuracy: 0.704
#  LR: 0.05, Momentum: 0.9, Weight: 5e-05, Accuracy: 0.800
#  LR: 0.05, Momentum: 0.9, Weight: 5e-06, Accuracy: 0.692
#  LR: 0.01, Momentum: 0.5, Weight: 0.5, Accuracy: 0.520
#  LR: 0.01, Momentum: 0.5, Weight: 0.05, Accuracy: 0.864
#  LR: 0.01, Momentum: 0.5, Weight: 0.005, Accuracy: 0.876
#  LR: 0.01, Momentum: 0.5, Weight: 0.0005, Accuracy: 0.868
#  LR: 0.01, Momentum: 0.5, Weight: 5e-05, Accuracy: 0.864
#  LR: 0.01, Momentum: 0.5, Weight: 5e-06, Accuracy: 0.852
#  LR: 0.01, Momentum: 0.7, Weight: 0.5, Accuracy: 0.520
#  LR: 0.01, Momentum: 0.7, Weight: 0.05, Accuracy: 0.860
#  LR: 0.01, Momentum: 0.7, Weight: 0.005, Accuracy: 0.856
#  LR: 0.01, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.872
#  LR: 0.01, Momentum: 0.7, Weight: 5e-05, Accuracy: 0.872
#  LR: 0.01, Momentum: 0.7, Weight: 5e-06, Accuracy: 0.856
#  LR: 0.01, Momentum: 0.9, Weight: 0.5, Accuracy: 0.520
#  LR: 0.01, Momentum: 0.9, Weight: 0.05, Accuracy: 0.888
#  LR: 0.01, Momentum: 0.9, Weight: 0.005, Accuracy: 0.876
#  LR: 0.01, Momentum: 0.9, Weight: 0.0005, Accuracy: 0.856
#  LR: 0.01, Momentum: 0.9, Weight: 5e-05, Accuracy: 0.868
#  LR: 0.01, Momentum: 0.9, Weight: 5e-06, Accuracy: 0.896
#  LR: 0.005, Momentum: 0.5, Weight: 0.5, Accuracy: 0.520
#  LR: 0.005, Momentum: 0.5, Weight: 0.05, Accuracy: 0.856
#  LR: 0.005, Momentum: 0.5, Weight: 0.005, Accuracy: 0.840
#  LR: 0.005, Momentum: 0.5, Weight: 0.0005, Accuracy: 0.840
#  LR: 0.005, Momentum: 0.5, Weight: 5e-05, Accuracy: 0.832
#  LR: 0.005, Momentum: 0.5, Weight: 5e-06, Accuracy: 0.872
#  LR: 0.005, Momentum: 0.7, Weight: 0.5, Accuracy: 0.520
#  LR: 0.005, Momentum: 0.7, Weight: 0.05, Accuracy: 0.864
#  LR: 0.005, Momentum: 0.7, Weight: 0.005, Accuracy: 0.856
#  LR: 0.005, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.876
#  LR: 0.005, Momentum: 0.7, Weight: 5e-05, Accuracy: 0.840
#  LR: 0.005, Momentum: 0.7, Weight: 5e-06, Accuracy: 0.852
#  LR: 0.005, Momentum: 0.9, Weight: 0.5, Accuracy: 0.520
#  LR: 0.005, Momentum: 0.9, Weight: 0.05, Accuracy: 0.872
#  LR: 0.005, Momentum: 0.9, Weight: 0.005, Accuracy: 0.868
#  LR: 0.005, Momentum: 0.9, Weight: 0.0005, Accuracy: 0.880
#  LR: 0.005, Momentum: 0.9, Weight: 5e-05, Accuracy: 0.900
#  LR: 0.005, Momentum: 0.9, Weight: 5e-06, Accuracy: 0.864
#  LR: 0.001, Momentum: 0.5, Weight: 0.5, Accuracy: 0.520
#  LR: 0.001, Momentum: 0.5, Weight: 0.05, Accuracy: 0.840
#  LR: 0.001, Momentum: 0.5, Weight: 0.005, Accuracy: 0.844
#  LR: 0.001, Momentum: 0.5, Weight: 0.0005, Accuracy: 0.880
#  LR: 0.001, Momentum: 0.5, Weight: 5e-05, Accuracy: 0.836
#  LR: 0.001, Momentum: 0.5, Weight: 5e-06, Accuracy: 0.836
#  LR: 0.001, Momentum: 0.7, Weight: 0.5, Accuracy: 0.520
#  LR: 0.001, Momentum: 0.7, Weight: 0.05, Accuracy: 0.860
#  LR: 0.001, Momentum: 0.7, Weight: 0.005, Accuracy: 0.868
#  LR: 0.001, Momentum: 0.7, Weight: 0.0005, Accuracy: 0.820
#  LR: 0.001, Momentum: 0.7, Weight: 5e-05, Accuracy: 0.876
#  LR: 0.001, Momentum: 0.7, Weight: 5e-06, Accuracy: 0.852
#  LR: 0.001, Momentum: 0.9, Weight: 0.5, Accuracy: 0.520
#  LR: 0.001, Momentum: 0.9, Weight: 0.05, Accuracy: 0.880
#  LR: 0.001, Momentum: 0.9, Weight: 0.005, Accuracy: 0.844
#  LR: 0.001, Momentum: 0.9, Weight: 0.0005, Accuracy: 0.856
#  LR: 0.001, Momentum: 0.9, Weight: 5e-05, Accuracy: 0.860
#  LR: 0.001, Momentum: 0.9, Weight: 5e-06, Accuracy: 0.876
# Done!

# %% [markdown]
# ### Plotting learning curves
#
# There are many way to produce data to be used in order to plot the learning curve. One of these is to export the output of the learning phase in a file, and then parse it with `parse_log.py` script, that it is already provided in caffe.
#
# **!Remember to edit the path**

# %%
# !/home/met/caffe-nv/build/tools/caffe train -solver DeepLearning/hdf5_classification/nonlinear_logreg_solver.prototxt 2>&1 | tee lenet_train.log
# Out:
# I1208 17:05:53.295796 25663 caffe.cpp:190] Use CPU.
# I1208 17:05:53.295946 25663 solver.cpp:48] Initializing solver from parameters:
# train_net: "DeepLearning/hdf5_classification/nonlinear_auto_train.prototxt"
# test_net: "DeepLearning/hdf5_classification/nonlinear_auto_test.prototxt"
# test_iter: 250
# test_interval: 100
# base_lr: 0.001
# display: 100
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 5e-06
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "DeepLearning/hdf5_classification/data/train"
# solver_mode: CPU
# I1208 17:05:53.296087 25663 solver.cpp:81] Creating training net from train_net file: DeepLearning/hdf5_classification/nonlinear_auto_train.prototxt
# I1208 17:05:53.296238 25663 net.cpp:52] Initializing net from parameters:
# state {
#   phase: TRAIN
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "DeepLearning/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 20
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "ip1"
#   top: "ip1"
# }
# layer {
#   name: "ip2"
#   type: "InnerProduct"
#   bottom: "ip1"
#   top: "ip2"
#   inner_product_param {
#     num_output: 20
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "ip2"
#   top: "ip2"
# }
# layer {
#   name: "ip3"
#   type: "InnerProduct"
#   bottom: "ip2"
#   top: "ip3"
#   inner_product_param {
#     num_output: 10
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "ip3"
#   top: "ip3"
# }
# layer {
#   name: "Dropout1"
#   type: "Dropout"
#   bottom: "ip3"
#   top: "ip3"
# }
# layer {
#   name: "ip4"
#   type: "InnerProduct"
#   bottom: "ip3"
#   top: "ip4"
#   inner_product_param {
#     num_output: 5
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "ip4"
#   top: "ip4"
# }
# layer {
#   name: "ip5"
#   type: "InnerProduct"
#   bottom: "ip4"
#   top: "ip5"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip4"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip4"
#   bottom: "label"
#   top: "loss"
# }
# I1208 17:05:53.296280 25663 layer_factory.hpp:77] Creating layer data
# I1208 17:05:53.296288 25663 net.cpp:94] Creating Layer data
# I1208 17:05:53.296289 25663 net.cpp:409] data -> data
# I1208 17:05:53.296299 25663 net.cpp:409] data -> label
# I1208 17:05:53.296304 25663 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: DeepLearning/hdf5_classification/data/train.txt
# I1208 17:05:53.296367 25663 hdf5_data_layer.cpp:93] Number of HDF5 files: 2
# I1208 17:05:53.296975 25663 hdf5.cpp:32] Datatype class: H5T_FLOAT
# I1208 17:05:53.297204 25663 net.cpp:144] Setting up data
# I1208 17:05:53.297210 25663 net.cpp:151] Top shape: 10 40 (400)
# I1208 17:05:53.297212 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.297214 25663 net.cpp:159] Memory required for data: 1640
# I1208 17:05:53.297216 25663 layer_factory.hpp:77] Creating layer label_data_1_split
# I1208 17:05:53.297220 25663 net.cpp:94] Creating Layer label_data_1_split
# I1208 17:05:53.297222 25663 net.cpp:435] label_data_1_split <- label
# I1208 17:05:53.297227 25663 net.cpp:409] label_data_1_split -> label_data_1_split_0
# I1208 17:05:53.297231 25663 net.cpp:409] label_data_1_split -> label_data_1_split_1
# I1208 17:05:53.297235 25663 net.cpp:144] Setting up label_data_1_split
# I1208 17:05:53.297237 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.297238 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.297240 25663 net.cpp:159] Memory required for data: 1720
# I1208 17:05:53.297240 25663 layer_factory.hpp:77] Creating layer ip1
# I1208 17:05:53.297245 25663 net.cpp:94] Creating Layer ip1
# I1208 17:05:53.297246 25663 net.cpp:435] ip1 <- data
# I1208 17:05:53.297250 25663 net.cpp:409] ip1 -> ip1
# I1208 17:05:53.297514 25663 net.cpp:144] Setting up ip1
# I1208 17:05:53.297528 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.297538 25663 net.cpp:159] Memory required for data: 2520
# I1208 17:05:53.297545 25663 layer_factory.hpp:77] Creating layer relu1
# I1208 17:05:53.297549 25663 net.cpp:94] Creating Layer relu1
# I1208 17:05:53.297551 25663 net.cpp:435] relu1 <- ip1
# I1208 17:05:53.297554 25663 net.cpp:396] relu1 -> ip1 (in-place)
# I1208 17:05:53.297556 25663 net.cpp:144] Setting up relu1
# I1208 17:05:53.297559 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.297559 25663 net.cpp:159] Memory required for data: 3320
# I1208 17:05:53.297560 25663 layer_factory.hpp:77] Creating layer ip2
# I1208 17:05:53.297564 25663 net.cpp:94] Creating Layer ip2
# I1208 17:05:53.297565 25663 net.cpp:435] ip2 <- ip1
# I1208 17:05:53.297569 25663 net.cpp:409] ip2 -> ip2
# I1208 17:05:53.297575 25663 net.cpp:144] Setting up ip2
# I1208 17:05:53.297577 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.297579 25663 net.cpp:159] Memory required for data: 4120
# I1208 17:05:53.297582 25663 layer_factory.hpp:77] Creating layer relu2
# I1208 17:05:53.297585 25663 net.cpp:94] Creating Layer relu2
# I1208 17:05:53.297585 25663 net.cpp:435] relu2 <- ip2
# I1208 17:05:53.297587 25663 net.cpp:396] relu2 -> ip2 (in-place)
# I1208 17:05:53.297590 25663 net.cpp:144] Setting up relu2
# I1208 17:05:53.297591 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.297592 25663 net.cpp:159] Memory required for data: 4920
# I1208 17:05:53.297593 25663 layer_factory.hpp:77] Creating layer ip3
# I1208 17:05:53.297595 25663 net.cpp:94] Creating Layer ip3
# I1208 17:05:53.297597 25663 net.cpp:435] ip3 <- ip2
# I1208 17:05:53.297598 25663 net.cpp:409] ip3 -> ip3
# I1208 17:05:53.297605 25663 net.cpp:144] Setting up ip3
# I1208 17:05:53.297607 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.297608 25663 net.cpp:159] Memory required for data: 5320
# I1208 17:05:53.297611 25663 layer_factory.hpp:77] Creating layer relu3
# I1208 17:05:53.297613 25663 net.cpp:94] Creating Layer relu3
# I1208 17:05:53.297615 25663 net.cpp:435] relu3 <- ip3
# I1208 17:05:53.297616 25663 net.cpp:396] relu3 -> ip3 (in-place)
# I1208 17:05:53.297618 25663 net.cpp:144] Setting up relu3
# I1208 17:05:53.297619 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.297621 25663 net.cpp:159] Memory required for data: 5720
# I1208 17:05:53.297622 25663 layer_factory.hpp:77] Creating layer Dropout1
# I1208 17:05:53.297626 25663 net.cpp:94] Creating Layer Dropout1
# I1208 17:05:53.297626 25663 net.cpp:435] Dropout1 <- ip3
# I1208 17:05:53.297628 25663 net.cpp:396] Dropout1 -> ip3 (in-place)
# I1208 17:05:53.297631 25663 net.cpp:144] Setting up Dropout1
# I1208 17:05:53.297633 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.297634 25663 net.cpp:159] Memory required for data: 6120
# I1208 17:05:53.297636 25663 layer_factory.hpp:77] Creating layer ip4
# I1208 17:05:53.297637 25663 net.cpp:94] Creating Layer ip4
# I1208 17:05:53.297638 25663 net.cpp:435] ip4 <- ip3
# I1208 17:05:53.297641 25663 net.cpp:409] ip4 -> ip4
# I1208 17:05:53.297646 25663 net.cpp:144] Setting up ip4
# I1208 17:05:53.297646 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.297647 25663 net.cpp:159] Memory required for data: 6320
# I1208 17:05:53.297649 25663 layer_factory.hpp:77] Creating layer relu4
# I1208 17:05:53.297652 25663 net.cpp:94] Creating Layer relu4
# I1208 17:05:53.297653 25663 net.cpp:435] relu4 <- ip4
# I1208 17:05:53.297654 25663 net.cpp:396] relu4 -> ip4 (in-place)
# I1208 17:05:53.297657 25663 net.cpp:144] Setting up relu4
# I1208 17:05:53.297658 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.297659 25663 net.cpp:159] Memory required for data: 6520
# I1208 17:05:53.297660 25663 layer_factory.hpp:77] Creating layer ip4_relu4_0_split
# I1208 17:05:53.297662 25663 net.cpp:94] Creating Layer ip4_relu4_0_split
# I1208 17:05:53.297663 25663 net.cpp:435] ip4_relu4_0_split <- ip4
# I1208 17:05:53.297667 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_0
# I1208 17:05:53.297669 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_1
# I1208 17:05:53.297672 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_2
# I1208 17:05:53.297677 25663 net.cpp:144] Setting up ip4_relu4_0_split
# I1208 17:05:53.297682 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.297683 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.297684 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.297685 25663 net.cpp:159] Memory required for data: 7120
# I1208 17:05:53.297688 25663 layer_factory.hpp:77] Creating layer ip5
# I1208 17:05:53.297689 25663 net.cpp:94] Creating Layer ip5
# I1208 17:05:53.297690 25663 net.cpp:435] ip5 <- ip4_relu4_0_split_0
# I1208 17:05:53.297693 25663 net.cpp:409] ip5 -> ip5
# I1208 17:05:53.297698 25663 net.cpp:144] Setting up ip5
# I1208 17:05:53.297700 25663 net.cpp:151] Top shape: 10 2 (20)
# I1208 17:05:53.297700 25663 net.cpp:159] Memory required for data: 7200
# I1208 17:05:53.297703 25663 layer_factory.hpp:77] Creating layer accuracy
# I1208 17:05:53.297706 25663 net.cpp:94] Creating Layer accuracy
# I1208 17:05:53.297708 25663 net.cpp:435] accuracy <- ip4_relu4_0_split_1
# I1208 17:05:53.297709 25663 net.cpp:435] accuracy <- label_data_1_split_0
# I1208 17:05:53.297713 25663 net.cpp:409] accuracy -> accuracy
# I1208 17:05:53.297715 25663 net.cpp:144] Setting up accuracy
# I1208 17:05:53.297718 25663 net.cpp:151] Top shape: (1)
# I1208 17:05:53.297719 25663 net.cpp:159] Memory required for data: 7204
# I1208 17:05:53.297719 25663 layer_factory.hpp:77] Creating layer loss
# I1208 17:05:53.297722 25663 net.cpp:94] Creating Layer loss
# I1208 17:05:53.297724 25663 net.cpp:435] loss <- ip4_relu4_0_split_2
# I1208 17:05:53.297725 25663 net.cpp:435] loss <- label_data_1_split_1
# I1208 17:05:53.297727 25663 net.cpp:409] loss -> loss
# I1208 17:05:53.297731 25663 layer_factory.hpp:77] Creating layer loss
# I1208 17:05:53.297737 25663 net.cpp:144] Setting up loss
# I1208 17:05:53.297739 25663 net.cpp:151] Top shape: (1)
# I1208 17:05:53.297740 25663 net.cpp:154]     with loss weight 1
# I1208 17:05:53.297745 25663 net.cpp:159] Memory required for data: 7208
# I1208 17:05:53.297747 25663 net.cpp:220] loss needs backward computation.
# I1208 17:05:53.297749 25663 net.cpp:222] accuracy does not need backward computation.
# I1208 17:05:53.297751 25663 net.cpp:222] ip5 does not need backward computation.
# I1208 17:05:53.297754 25663 net.cpp:220] ip4_relu4_0_split needs backward computation.
# I1208 17:05:53.297755 25663 net.cpp:220] relu4 needs backward computation.
# I1208 17:05:53.297755 25663 net.cpp:220] ip4 needs backward computation.
# I1208 17:05:53.297757 25663 net.cpp:220] Dropout1 needs backward computation.
# I1208 17:05:53.297758 25663 net.cpp:220] relu3 needs backward computation.
# I1208 17:05:53.297760 25663 net.cpp:220] ip3 needs backward computation.
# I1208 17:05:53.297760 25663 net.cpp:220] relu2 needs backward computation.
# I1208 17:05:53.297761 25663 net.cpp:220] ip2 needs backward computation.
# I1208 17:05:53.297763 25663 net.cpp:220] relu1 needs backward computation.
# I1208 17:05:53.297765 25663 net.cpp:220] ip1 needs backward computation.
# I1208 17:05:53.297766 25663 net.cpp:222] label_data_1_split does not need backward computation.
# I1208 17:05:53.297767 25663 net.cpp:222] data does not need backward computation.
# I1208 17:05:53.297770 25663 net.cpp:264] This network produces output accuracy
# I1208 17:05:53.297770 25663 net.cpp:264] This network produces output ip5
# I1208 17:05:53.297771 25663 net.cpp:264] This network produces output loss
# I1208 17:05:53.297780 25663 net.cpp:284] Network initialization done.
# I1208 17:05:53.297878 25663 solver.cpp:181] Creating test net (#0) specified by test_net file: DeepLearning/hdf5_classification/nonlinear_auto_test.prototxt
# I1208 17:05:53.297916 25663 net.cpp:52] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "DeepLearning/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 20
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "ip1"
#   top: "ip1"
# }
# layer {
#   name: "ip2"
#   type: "InnerProduct"
#   bottom: "ip1"
#   top: "ip2"
#   inner_product_param {
#     num_output: 20
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "ip2"
#   top: "ip2"
# }
# layer {
#   name: "ip3"
#   type: "InnerProduct"
#   bottom: "ip2"
#   top: "ip3"
#   inner_product_param {
#     num_output: 10
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "ip3"
#   top: "ip3"
# }
# layer {
#   name: "Dropout1"
#   type: "Dropout"
#   bottom: "ip3"
#   top: "ip3"
# }
# layer {
#   name: "ip4"
#   type: "InnerProduct"
#   bottom: "ip3"
#   top: "ip4"
#   inner_product_param {
#     num_output: 5
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "ip4"
#   top: "ip4"
# }
# layer {
#   name: "ip5"
#   type: "InnerProduct"
#   bottom: "ip4"
#   top: "ip5"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip4"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip4"
#   bottom: "label"
#   top: "loss"
# }
# I1208 17:05:53.297950 25663 layer_factory.hpp:77] Creating layer data
# I1208 17:05:53.297955 25663 net.cpp:94] Creating Layer data
# I1208 17:05:53.297956 25663 net.cpp:409] data -> data
# I1208 17:05:53.297960 25663 net.cpp:409] data -> label
# I1208 17:05:53.297962 25663 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: DeepLearning/hdf5_classification/data/test.txt
# I1208 17:05:53.298028 25663 hdf5_data_layer.cpp:93] Number of HDF5 files: 1
# I1208 17:05:53.298807 25663 net.cpp:144] Setting up data
# I1208 17:05:53.298813 25663 net.cpp:151] Top shape: 10 40 (400)
# I1208 17:05:53.298815 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.298816 25663 net.cpp:159] Memory required for data: 1640
# I1208 17:05:53.298818 25663 layer_factory.hpp:77] Creating layer label_data_1_split
# I1208 17:05:53.298821 25663 net.cpp:94] Creating Layer label_data_1_split
# I1208 17:05:53.298822 25663 net.cpp:435] label_data_1_split <- label
# I1208 17:05:53.298825 25663 net.cpp:409] label_data_1_split -> label_data_1_split_0
# I1208 17:05:53.298830 25663 net.cpp:409] label_data_1_split -> label_data_1_split_1
# I1208 17:05:53.298832 25663 net.cpp:144] Setting up label_data_1_split
# I1208 17:05:53.298835 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.298835 25663 net.cpp:151] Top shape: 10 (10)
# I1208 17:05:53.298837 25663 net.cpp:159] Memory required for data: 1720
# I1208 17:05:53.298838 25663 layer_factory.hpp:77] Creating layer ip1
# I1208 17:05:53.298840 25663 net.cpp:94] Creating Layer ip1
# I1208 17:05:53.298842 25663 net.cpp:435] ip1 <- data
# I1208 17:05:53.298844 25663 net.cpp:409] ip1 -> ip1
# I1208 17:05:53.298853 25663 net.cpp:144] Setting up ip1
# I1208 17:05:53.298856 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.298856 25663 net.cpp:159] Memory required for data: 2520
# I1208 17:05:53.298861 25663 layer_factory.hpp:77] Creating layer relu1
# I1208 17:05:53.298863 25663 net.cpp:94] Creating Layer relu1
# I1208 17:05:53.298864 25663 net.cpp:435] relu1 <- ip1
# I1208 17:05:53.298866 25663 net.cpp:396] relu1 -> ip1 (in-place)
# I1208 17:05:53.298868 25663 net.cpp:144] Setting up relu1
# I1208 17:05:53.298871 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.298871 25663 net.cpp:159] Memory required for data: 3320
# I1208 17:05:53.298872 25663 layer_factory.hpp:77] Creating layer ip2
# I1208 17:05:53.298874 25663 net.cpp:94] Creating Layer ip2
# I1208 17:05:53.298877 25663 net.cpp:435] ip2 <- ip1
# I1208 17:05:53.298877 25663 net.cpp:409] ip2 -> ip2
# I1208 17:05:53.298883 25663 net.cpp:144] Setting up ip2
# I1208 17:05:53.298887 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.298887 25663 net.cpp:159] Memory required for data: 4120
# I1208 17:05:53.298889 25663 layer_factory.hpp:77] Creating layer relu2
# I1208 17:05:53.298892 25663 net.cpp:94] Creating Layer relu2
# I1208 17:05:53.298893 25663 net.cpp:435] relu2 <- ip2
# I1208 17:05:53.298894 25663 net.cpp:396] relu2 -> ip2 (in-place)
# I1208 17:05:53.298897 25663 net.cpp:144] Setting up relu2
# I1208 17:05:53.298898 25663 net.cpp:151] Top shape: 10 20 (200)
# I1208 17:05:53.298904 25663 net.cpp:159] Memory required for data: 4920
# I1208 17:05:53.298905 25663 layer_factory.hpp:77] Creating layer ip3
# I1208 17:05:53.298907 25663 net.cpp:94] Creating Layer ip3
# I1208 17:05:53.298908 25663 net.cpp:435] ip3 <- ip2
# I1208 17:05:53.298912 25663 net.cpp:409] ip3 -> ip3
# I1208 17:05:53.298916 25663 net.cpp:144] Setting up ip3
# I1208 17:05:53.298918 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.298918 25663 net.cpp:159] Memory required for data: 5320
# I1208 17:05:53.298923 25663 layer_factory.hpp:77] Creating layer relu3
# I1208 17:05:53.298923 25663 net.cpp:94] Creating Layer relu3
# I1208 17:05:53.298925 25663 net.cpp:435] relu3 <- ip3
# I1208 17:05:53.298926 25663 net.cpp:396] relu3 -> ip3 (in-place)
# I1208 17:05:53.298928 25663 net.cpp:144] Setting up relu3
# I1208 17:05:53.298930 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.298931 25663 net.cpp:159] Memory required for data: 5720
# I1208 17:05:53.298933 25663 layer_factory.hpp:77] Creating layer Dropout1
# I1208 17:05:53.298934 25663 net.cpp:94] Creating Layer Dropout1
# I1208 17:05:53.298936 25663 net.cpp:435] Dropout1 <- ip3
# I1208 17:05:53.298938 25663 net.cpp:396] Dropout1 -> ip3 (in-place)
# I1208 17:05:53.298940 25663 net.cpp:144] Setting up Dropout1
# I1208 17:05:53.298941 25663 net.cpp:151] Top shape: 10 10 (100)
# I1208 17:05:53.298943 25663 net.cpp:159] Memory required for data: 6120
# I1208 17:05:53.298944 25663 layer_factory.hpp:77] Creating layer ip4
# I1208 17:05:53.298945 25663 net.cpp:94] Creating Layer ip4
# I1208 17:05:53.298948 25663 net.cpp:435] ip4 <- ip3
# I1208 17:05:53.298949 25663 net.cpp:409] ip4 -> ip4
# I1208 17:05:53.298954 25663 net.cpp:144] Setting up ip4
# I1208 17:05:53.298955 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.298956 25663 net.cpp:159] Memory required for data: 6320
# I1208 17:05:53.298959 25663 layer_factory.hpp:77] Creating layer relu4
# I1208 17:05:53.298960 25663 net.cpp:94] Creating Layer relu4
# I1208 17:05:53.298961 25663 net.cpp:435] relu4 <- ip4
# I1208 17:05:53.298964 25663 net.cpp:396] relu4 -> ip4 (in-place)
# I1208 17:05:53.298965 25663 net.cpp:144] Setting up relu4
# I1208 17:05:53.298966 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.298967 25663 net.cpp:159] Memory required for data: 6520
# I1208 17:05:53.298969 25663 layer_factory.hpp:77] Creating layer ip4_relu4_0_split
# I1208 17:05:53.298970 25663 net.cpp:94] Creating Layer ip4_relu4_0_split
# I1208 17:05:53.298972 25663 net.cpp:435] ip4_relu4_0_split <- ip4
# I1208 17:05:53.298974 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_0
# I1208 17:05:53.298977 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_1
# I1208 17:05:53.298980 25663 net.cpp:409] ip4_relu4_0_split -> ip4_relu4_0_split_2
# I1208 17:05:53.298984 25663 net.cpp:144] Setting up ip4_relu4_0_split
# I1208 17:05:53.298985 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.298986 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.298988 25663 net.cpp:151] Top shape: 10 5 (50)
# I1208 17:05:53.298990 25663 net.cpp:159] Memory required for data: 7120
# I1208 17:05:53.298990 25663 layer_factory.hpp:77] Creating layer ip5
# I1208 17:05:53.298992 25663 net.cpp:94] Creating Layer ip5
# I1208 17:05:53.298993 25663 net.cpp:435] ip5 <- ip4_relu4_0_split_0
# I1208 17:05:53.298995 25663 net.cpp:409] ip5 -> ip5
# I1208 17:05:53.299000 25663 net.cpp:144] Setting up ip5
# I1208 17:05:53.299001 25663 net.cpp:151] Top shape: 10 2 (20)
# I1208 17:05:53.299002 25663 net.cpp:159] Memory required for data: 7200
# I1208 17:05:53.299005 25663 layer_factory.hpp:77] Creating layer accuracy
# I1208 17:05:53.299007 25663 net.cpp:94] Creating Layer accuracy
# I1208 17:05:53.299008 25663 net.cpp:435] accuracy <- ip4_relu4_0_split_1
# I1208 17:05:53.299010 25663 net.cpp:435] accuracy <- label_data_1_split_0
# I1208 17:05:53.299013 25663 net.cpp:409] accuracy -> accuracy
# I1208 17:05:53.299015 25663 net.cpp:144] Setting up accuracy
# I1208 17:05:53.299016 25663 net.cpp:151] Top shape: (1)
# I1208 17:05:53.299018 25663 net.cpp:159] Memory required for data: 7204
# I1208 17:05:53.299020 25663 layer_factory.hpp:77] Creating layer loss
# I1208 17:05:53.299026 25663 net.cpp:94] Creating Layer loss
# I1208 17:05:53.299026 25663 net.cpp:435] loss <- ip4_relu4_0_split_2
# I1208 17:05:53.299028 25663 net.cpp:435] loss <- label_data_1_split_1
# I1208 17:05:53.299031 25663 net.cpp:409] loss -> loss
# I1208 17:05:53.299033 25663 layer_factory.hpp:77] Creating layer loss
# I1208 17:05:53.299038 25663 net.cpp:144] Setting up loss
# I1208 17:05:53.299041 25663 net.cpp:151] Top shape: (1)
# I1208 17:05:53.299041 25663 net.cpp:154]     with loss weight 1
# I1208 17:05:53.299043 25663 net.cpp:159] Memory required for data: 7208
# I1208 17:05:53.299044 25663 net.cpp:220] loss needs backward computation.
# I1208 17:05:53.299047 25663 net.cpp:222] accuracy does not need backward computation.
# I1208 17:05:53.299048 25663 net.cpp:222] ip5 does not need backward computation.
# I1208 17:05:53.299051 25663 net.cpp:220] ip4_relu4_0_split needs backward computation.
# I1208 17:05:53.299052 25663 net.cpp:220] relu4 needs backward computation.
# I1208 17:05:53.299053 25663 net.cpp:220] ip4 needs backward computation.
# I1208 17:05:53.299054 25663 net.cpp:220] Dropout1 needs backward computation.
# I1208 17:05:53.299055 25663 net.cpp:220] relu3 needs backward computation.
# I1208 17:05:53.299057 25663 net.cpp:220] ip3 needs backward computation.
# I1208 17:05:53.299058 25663 net.cpp:220] relu2 needs backward computation.
# I1208 17:05:53.299059 25663 net.cpp:220] ip2 needs backward computation.
# I1208 17:05:53.299060 25663 net.cpp:220] relu1 needs backward computation.
# I1208 17:05:53.299062 25663 net.cpp:220] ip1 needs backward computation.
# I1208 17:05:53.299063 25663 net.cpp:222] label_data_1_split does not need backward computation.
# I1208 17:05:53.299065 25663 net.cpp:222] data does not need backward computation.
# I1208 17:05:53.299067 25663 net.cpp:264] This network produces output accuracy
# I1208 17:05:53.299067 25663 net.cpp:264] This network produces output ip5
# I1208 17:05:53.299069 25663 net.cpp:264] This network produces output loss
# I1208 17:05:53.299075 25663 net.cpp:284] Network initialization done.
# I1208 17:05:53.299090 25663 solver.cpp:60] Solver scaffolding done.
# I1208 17:05:53.299103 25663 caffe.cpp:231] Starting Optimization
# I1208 17:05:53.299105 25663 solver.cpp:304] Solving
# I1208 17:05:53.299106 25663 solver.cpp:305] Learning Rate Policy: step
# I1208 17:05:53.299113 25663 solver.cpp:362] Iteration 0, Testing net (#0)
# I1208 17:05:53.322530 25663 solver.cpp:429]     Test net output #0: accuracy = 0.028
# I1208 17:05:53.322546 25663 solver.cpp:429]     Test net output #1: ip5 = -0.343514
# I1208 17:05:53.322547 25663 solver.cpp:429]     Test net output #2: ip5 = 0.099323
# I1208 17:05:53.322549 25663 solver.cpp:429]     Test net output #3: ip5 = -0.308352
# I1208 17:05:53.322551 25663 solver.cpp:429]     Test net output #4: ip5 = 0.079364
# I1208 17:05:53.322553 25663 solver.cpp:429]     Test net output #5: ip5 = -0.390176
# I1208 17:05:53.322554 25663 solver.cpp:429]     Test net output #6: ip5 = 0.190969
# I1208 17:05:53.322556 25663 solver.cpp:429]     Test net output #7: ip5 = -0.27795
# I1208 17:05:53.322557 25663 solver.cpp:429]     Test net output #8: ip5 = 0.0826901
# I1208 17:05:53.322559 25663 solver.cpp:429]     Test net output #9: ip5 = -0.34741
# I1208 17:05:53.322561 25663 solver.cpp:429]     Test net output #10: ip5 = 0.126959
# I1208 17:05:53.322562 25663 solver.cpp:429]     Test net output #11: ip5 = -0.348734
# I1208 17:05:53.322564 25663 solver.cpp:429]     Test net output #12: ip5 = 0.117929
# I1208 17:05:53.322566 25663 solver.cpp:429]     Test net output #13: ip5 = -0.331681
# I1208 17:05:53.322568 25663 solver.cpp:429]     Test net output #14: ip5 = 0.10612
# I1208 17:05:53.322569 25663 solver.cpp:429]     Test net output #15: ip5 = -0.298944
# I1208 17:05:53.322571 25663 solver.cpp:429]     Test net output #16: ip5 = 0.0884468
# I1208 17:05:53.322573 25663 solver.cpp:429]     Test net output #17: ip5 = -0.299483
# I1208 17:05:53.322574 25663 solver.cpp:429]     Test net output #18: ip5 = 0.12515
# I1208 17:05:53.322576 25663 solver.cpp:429]     Test net output #19: ip5 = -0.201935
# I1208 17:05:53.322597 25663 solver.cpp:429]     Test net output #20: ip5 = 0.0311356
# I1208 17:05:53.322602 25663 solver.cpp:429]     Test net output #21: loss = 1.8054 (* 1 = 1.8054 loss)
# I1208 17:05:53.322695 25663 solver.cpp:242] Iteration 0 (0 iter/s, 0.023s/100 iter), loss = 2.01309
# I1208 17:05:53.322700 25663 solver.cpp:261]     Train net output #0: accuracy = 0.1
# I1208 17:05:53.322702 25663 solver.cpp:261]     Train net output #1: ip5 = -0.675806
# I1208 17:05:53.322705 25663 solver.cpp:261]     Train net output #2: ip5 = 0.360866
# I1208 17:05:53.322705 25663 solver.cpp:261]     Train net output #3: ip5 = -0.536064
# I1208 17:05:53.322707 25663 solver.cpp:261]     Train net output #4: ip5 = 0.296126
# I1208 17:05:53.322708 25663 solver.cpp:261]     Train net output #5: ip5 = -0.352639
# I1208 17:05:53.322710 25663 solver.cpp:261]     Train net output #6: ip5 = 0.300676
# I1208 17:05:53.322712 25663 solver.cpp:261]     Train net output #7: ip5 = -0.0870189
# I1208 17:05:53.322713 25663 solver.cpp:261]     Train net output #8: ip5 = 0.0895609
# I1208 17:05:53.322715 25663 solver.cpp:261]     Train net output #9: ip5 = -1.42454
# I1208 17:05:53.322717 25663 solver.cpp:261]     Train net output #10: ip5 = 0.675527
# I1208 17:05:53.322718 25663 solver.cpp:261]     Train net output #11: ip5 = 0.0675279
# I1208 17:05:53.322721 25663 solver.cpp:261]     Train net output #12: ip5 = -0.0102567
# I1208 17:05:53.322721 25663 solver.cpp:261]     Train net output #13: ip5 = 0.0546804
# I1208 17:05:53.322723 25663 solver.cpp:261]     Train net output #14: ip5 = -0.0189391
# I1208 17:05:53.322726 25663 solver.cpp:261]     Train net output #15: ip5 = -0.230692
# I1208 17:05:53.322726 25663 solver.cpp:261]     Train net output #16: ip5 = -0.00733018
# I1208 17:05:53.322728 25663 solver.cpp:261]     Train net output #17: ip5 = -1.19608
# I1208 17:05:53.322731 25663 solver.cpp:261]     Train net output #18: ip5 = 0.0510307
# I1208 17:05:53.322731 25663 solver.cpp:261]     Train net output #19: ip5 = 0.00325867
# I1208 17:05:53.322733 25663 solver.cpp:261]     Train net output #20: ip5 = -0.0086368
# I1208 17:05:53.322736 25663 solver.cpp:261]     Train net output #21: loss = 2.01309 (* 1 = 2.01309 loss)
# I1208 17:05:53.322741 25663 sgd_solver.cpp:106] Iteration 0, lr = 0.001
# I1208 17:05:53.325314 25663 solver.cpp:362] Iteration 100, Testing net (#0)
# I1208 17:05:53.327931 25663 solver.cpp:429]     Test net output #0: accuracy = 0.512
# I1208 17:05:53.327945 25663 solver.cpp:429]     Test net output #1: ip5 = 1.21409
# I1208 17:05:53.327947 25663 solver.cpp:429]     Test net output #2: ip5 = -0.951771
# I1208 17:05:53.327950 25663 solver.cpp:429]     Test net output #3: ip5 = 1.24669
# I1208 17:05:53.327951 25663 solver.cpp:429]     Test net output #4: ip5 = -0.963888
# I1208 17:05:53.327953 25663 solver.cpp:429]     Test net output #5: ip5 = 1.01982
# I1208 17:05:53.327955 25663 solver.cpp:429]     Test net output #6: ip5 = -0.805641
# I1208 17:05:53.327956 25663 solver.cpp:429]     Test net output #7: ip5 = 1.19217
# I1208 17:05:53.327958 25663 solver.cpp:429]     Test net output #8: ip5 = -0.924467
# I1208 17:05:53.327960 25663 solver.cpp:429]     Test net output #9: ip5 = 1.13741
# I1208 17:05:53.327961 25663 solver.cpp:429]     Test net output #10: ip5 = -0.879752
# I1208 17:05:53.327963 25663 solver.cpp:429]     Test net output #11: ip5 = 1.18953
# I1208 17:05:53.327965 25663 solver.cpp:429]     Test net output #12: ip5 = -0.929793
# I1208 17:05:53.327966 25663 solver.cpp:429]     Test net output #13: ip5 = 1.24947
# I1208 17:05:53.327968 25663 solver.cpp:429]     Test net output #14: ip5 = -0.97247
# I1208 17:05:53.327970 25663 solver.cpp:429]     Test net output #15: ip5 = 1.1165
# I1208 17:05:53.327972 25663 solver.cpp:429]     Test net output #16: ip5 = -0.875214
# I1208 17:05:53.327975 25663 solver.cpp:429]     Test net output #17: ip5 = 1.11674
# I1208 17:05:53.327976 25663 solver.cpp:429]     Test net output #18: ip5 = -0.871743
# I1208 17:05:53.327977 25663 solver.cpp:429]     Test net output #19: ip5 = 1.12882
# I1208 17:05:53.327980 25663 solver.cpp:429]     Test net output #20: ip5 = -0.840453
# I1208 17:05:53.327996 25663 solver.cpp:429]     Test net output #21: loss = 0.96359 (* 1 = 0.96359 loss)
# I1208 17:05:53.328032 25663 solver.cpp:242] Iteration 100 (20000 iter/s, 0.005s/100 iter), loss = 1.30036
# I1208 17:05:53.328037 25663 solver.cpp:261]     Train net output #0: accuracy = 0.2
# I1208 17:05:53.328038 25663 solver.cpp:261]     Train net output #1: ip5 = 2.60675
# I1208 17:05:53.328040 25663 solver.cpp:261]     Train net output #2: ip5 = -1.56886
# I1208 17:05:53.328042 25663 solver.cpp:261]     Train net output #3: ip5 = 1.97237
# I1208 17:05:53.328043 25663 solver.cpp:261]     Train net output #4: ip5 = -1.55254
# I1208 17:05:53.328045 25663 solver.cpp:261]     Train net output #5: ip5 = 0.262585
# I1208 17:05:53.328047 25663 solver.cpp:261]     Train net output #6: ip5 = -0.475216
# I1208 17:05:53.328049 25663 solver.cpp:261]     Train net output #7: ip5 = 0.260506
# I1208 17:05:53.328052 25663 solver.cpp:261]     Train net output #8: ip5 = -0.257232
# I1208 17:05:53.328052 25663 solver.cpp:261]     Train net output #9: ip5 = 0.511743
# I1208 17:05:53.328054 25663 solver.cpp:261]     Train net output #10: ip5 = -0.232954
# I1208 17:05:53.328057 25663 solver.cpp:261]     Train net output #11: ip5 = 2.56903
# I1208 17:05:53.328058 25663 solver.cpp:261]     Train net output #12: ip5 = -1.88147
# I1208 17:05:53.328059 25663 solver.cpp:261]     Train net output #13: ip5 = 1.5609
# I1208 17:05:53.328061 25663 solver.cpp:261]     Train net output #14: ip5 = -1.23149
# I1208 17:05:53.328063 25663 solver.cpp:261]     Train net output #15: ip5 = 0.165583
# I1208 17:05:53.328065 25663 solver.cpp:261]     Train net output #16: ip5 = -0.426016
# I1208 17:05:53.328066 25663 solver.cpp:261]     Train net output #17: ip5 = 2.19172
# I1208 17:05:53.328069 25663 solver.cpp:261]     Train net output #18: ip5 = -1.69345
# I1208 17:05:53.328071 25663 solver.cpp:261]     Train net output #19: ip5 = 0.559204
# I1208 17:05:53.328073 25663 solver.cpp:261]     Train net output #20: ip5 = -0.295873
# I1208 17:05:53.328075 25663 solver.cpp:261]     Train net output #21: loss = 1.30036 (* 1 = 1.30036 loss)
# I1208 17:05:53.328078 25663 sgd_solver.cpp:106] Iteration 100, lr = 0.001
# I1208 17:05:53.330256 25663 solver.cpp:362] Iteration 200, Testing net (#0)
# I1208 17:05:53.332825 25663 solver.cpp:429]     Test net output #0: accuracy = 0.704001
# I1208 17:05:53.332834 25663 solver.cpp:429]     Test net output #1: ip5 = 2.85289
# I1208 17:05:53.332836 25663 solver.cpp:429]     Test net output #2: ip5 = -1.96928
# I1208 17:05:53.332839 25663 solver.cpp:429]     Test net output #3: ip5 = 2.8493
# I1208 17:05:53.332840 25663 solver.cpp:429]     Test net output #4: ip5 = -1.96907
# I1208 17:05:53.332841 25663 solver.cpp:429]     Test net output #5: ip5 = 2.40537
# I1208 17:05:53.332844 25663 solver.cpp:429]     Test net output #6: ip5 = -1.65782
# I1208 17:05:53.332845 25663 solver.cpp:429]     Test net output #7: ip5 = 2.77134
# I1208 17:05:53.332846 25663 solver.cpp:429]     Test net output #8: ip5 = -1.90673
# I1208 17:05:53.332849 25663 solver.cpp:429]     Test net output #9: ip5 = 2.6595
# I1208 17:05:53.332849 25663 solver.cpp:429]     Test net output #10: ip5 = -1.82458
# I1208 17:05:53.332851 25663 solver.cpp:429]     Test net output #11: ip5 = 2.70284
# I1208 17:05:53.332854 25663 solver.cpp:429]     Test net output #12: ip5 = -1.87474
# I1208 17:05:53.332854 25663 solver.cpp:429]     Test net output #13: ip5 = 2.877
# I1208 17:05:53.332856 25663 solver.cpp:429]     Test net output #14: ip5 = -1.97972
# I1208 17:05:53.332859 25663 solver.cpp:429]     Test net output #15: ip5 = 2.57294
# I1208 17:05:53.332859 25663 solver.cpp:429]     Test net output #16: ip5 = -1.78814
# I1208 17:05:53.332861 25663 solver.cpp:429]     Test net output #17: ip5 = 2.72212
# I1208 17:05:53.332862 25663 solver.cpp:429]     Test net output #18: ip5 = -1.88396
# I1208 17:05:53.332864 25663 solver.cpp:429]     Test net output #19: ip5 = 2.59848
# I1208 17:05:53.332866 25663 solver.cpp:429]     Test net output #20: ip5 = -1.74116
# I1208 17:05:53.332870 25663 solver.cpp:429]     Test net output #21: loss = 0.704704 (* 1 = 0.704704 loss)
# I1208 17:05:53.332907 25663 solver.cpp:242] Iteration 200 (25000 iter/s, 0.004s/100 iter), loss = 0.698314
# I1208 17:05:53.332912 25663 solver.cpp:261]     Train net output #0: accuracy = 0.7
# I1208 17:05:53.332914 25663 solver.cpp:261]     Train net output #1: ip5 = 3.57015
# I1208 17:05:53.332916 25663 solver.cpp:261]     Train net output #2: ip5 = -2.47437
# I1208 17:05:53.332917 25663 solver.cpp:261]     Train net output #3: ip5 = 0.96042
# I1208 17:05:53.332919 25663 solver.cpp:261]     Train net output #4: ip5 = -0.654766
# I1208 17:05:53.332921 25663 solver.cpp:261]     Train net output #5: ip5 = 7.00758
# I1208 17:05:53.332922 25663 solver.cpp:261]     Train net output #6: ip5 = -4.79035
# I1208 17:05:53.332924 25663 solver.cpp:261]     Train net output #7: ip5 = 2.3975
# I1208 17:05:53.332926 25663 solver.cpp:261]     Train net output #8: ip5 = -1.72797
# I1208 17:05:53.332927 25663 solver.cpp:261]     Train net output #9: ip5 = 6.16915
# I1208 17:05:53.332929 25663 solver.cpp:261]     Train net output #10: ip5 = -3.86625
# I1208 17:05:53.332931 25663 solver.cpp:261]     Train net output #11: ip5 = 2.19545
# I1208 17:05:53.332933 25663 solver.cpp:261]     Train net output #12: ip5 = -1.40798
# I1208 17:05:53.332934 25663 solver.cpp:261]     Train net output #13: ip5 = 1.7071
# I1208 17:05:53.332937 25663 solver.cpp:261]     Train net output #14: ip5 = -1.49994
# I1208 17:05:53.332937 25663 solver.cpp:261]     Train net output #15: ip5 = 2.30646
# I1208 17:05:53.332939 25663 solver.cpp:261]     Train net output #16: ip5 = -1.37817
# I1208 17:05:53.332942 25663 solver.cpp:261]     Train net output #17: ip5 = 2.6145
# I1208 17:05:53.332942 25663 solver.cpp:261]     Train net output #18: ip5 = -1.67821
# I1208 17:05:53.332944 25663 solver.cpp:261]     Train net output #19: ip5 = 1.08261
# I1208 17:05:53.332947 25663 solver.cpp:261]     Train net output #20: ip5 = -0.730305
# I1208 17:05:53.332948 25663 solver.cpp:261]     Train net output #21: loss = 0.698314 (* 1 = 0.698314 loss)
# I1208 17:05:53.332950 25663 sgd_solver.cpp:106] Iteration 200, lr = 0.001
# I1208 17:05:53.334986 25663 solver.cpp:362] Iteration 300, Testing net (#0)
# I1208 17:05:53.337550 25663 solver.cpp:429]     Test net output #0: accuracy = 0.647999
# I1208 17:05:53.337566 25663 solver.cpp:429]     Test net output #1: ip5 = 3.94586
# I1208 17:05:53.337568 25663 solver.cpp:429]     Test net output #2: ip5 = -2.80021
# I1208 17:05:53.337569 25663 solver.cpp:429]     Test net output #3: ip5 = 3.91711
# I1208 17:05:53.337571 25663 solver.cpp:429]     Test net output #4: ip5 = -2.78504
# I1208 17:05:53.337574 25663 solver.cpp:429]     Test net output #5: ip5 = 3.28666
# I1208 17:05:53.337574 25663 solver.cpp:429]     Test net output #6: ip5 = -2.33043
# I1208 17:05:53.337576 25663 solver.cpp:429]     Test net output #7: ip5 = 3.79562
# I1208 17:05:53.337579 25663 solver.cpp:429]     Test net output #8: ip5 = -2.6908
# I1208 17:05:53.337579 25663 solver.cpp:429]     Test net output #9: ip5 = 3.66586
# I1208 17:05:53.337581 25663 solver.cpp:429]     Test net output #10: ip5 = -2.58732
# I1208 17:05:53.337584 25663 solver.cpp:429]     Test net output #11: ip5 = 3.70203
# I1208 17:05:53.337584 25663 solver.cpp:429]     Test net output #12: ip5 = -2.64515
# I1208 17:05:53.337586 25663 solver.cpp:429]     Test net output #13: ip5 = 3.94792
# I1208 17:05:53.337589 25663 solver.cpp:429]     Test net output #14: ip5 = -2.78942
# I1208 17:05:53.337589 25663 solver.cpp:429]     Test net output #15: ip5 = 3.50158
# I1208 17:05:53.337591 25663 solver.cpp:429]     Test net output #16: ip5 = -2.49628
# I1208 17:05:53.337594 25663 solver.cpp:429]     Test net output #17: ip5 = 3.7744
# I1208 17:05:53.337594 25663 solver.cpp:429]     Test net output #18: ip5 = -2.695
# I1208 17:05:53.337596 25663 solver.cpp:429]     Test net output #19: ip5 = 3.61004
# I1208 17:05:53.337599 25663 solver.cpp:429]     Test net output #20: ip5 = -2.51338
# I1208 17:05:53.337601 25663 solver.cpp:429]     Test net output #21: loss = 0.648427 (* 1 = 0.648427 loss)
# I1208 17:05:53.337990 25663 solver.cpp:242] Iteration 300 (20000 iter/s, 0.005s/100 iter), loss = 0.656124
# I1208 17:05:53.338006 25663 solver.cpp:261]     Train net output #0: accuracy = 0.6
# I1208 17:05:53.338008 25663 solver.cpp:261]     Train net output #1: ip5 = 1.61797
# I1208 17:05:53.338011 25663 solver.cpp:261]     Train net output #2: ip5 = -1.07604
# I1208 17:05:53.338013 25663 solver.cpp:261]     Train net output #3: ip5 = 1.65751
# I1208 17:05:53.338014 25663 solver.cpp:261]     Train net output #4: ip5 = -1.1517
# I1208 17:05:53.338016 25663 solver.cpp:261]     Train net output #5: ip5 = 1.94432
# I1208 17:05:53.338018 25663 solver.cpp:261]     Train net output #6: ip5 = -1.30745
# I1208 17:05:53.338019 25663 solver.cpp:261]     Train net output #7: ip5 = 3.35173
# I1208 17:05:53.338021 25663 solver.cpp:261]     Train net output #8: ip5 = -2.37571
# I1208 17:05:53.338023 25663 solver.cpp:261]     Train net output #9: ip5 = 4.53883
# I1208 17:05:53.338024 25663 solver.cpp:261]     Train net output #10: ip5 = -3.46747
# I1208 17:05:53.338027 25663 solver.cpp:261]     Train net output #11: ip5 = 3.98455
# I1208 17:05:53.338027 25663 solver.cpp:261]     Train net output #12: ip5 = -2.83426
# I1208 17:05:53.338029 25663 solver.cpp:261]     Train net output #13: ip5 = 3.5168
# I1208 17:05:53.338032 25663 solver.cpp:261]     Train net output #14: ip5 = -2.4878
# I1208 17:05:53.338032 25663 solver.cpp:261]     Train net output #15: ip5 = 2.62885
# I1208 17:05:53.338034 25663 solver.cpp:261]     Train net output #16: ip5 = -1.72794
# I1208 17:05:53.338037 25663 solver.cpp:261]     Train net output #17: ip5 = 11.3065
# I1208 17:05:53.338038 25663 solver.cpp:261]     Train net output #18: ip5 = -8.67391
# I1208 17:05:53.338039 25663 solver.cpp:261]     Train net output #19: ip5 = 3.02824
# I1208 17:05:53.338042 25663 solver.cpp:261]     Train net output #20: ip5 = -2.16106
# I1208 17:05:53.338045 25663 solver.cpp:261]     Train net output #21: loss = 0.656124 (* 1 = 0.656124 loss)
# I1208 17:05:53.338048 25663 sgd_solver.cpp:106] Iteration 300, lr = 0.001
# I1208 17:05:53.340018 25663 solver.cpp:362] Iteration 400, Testing net (#0)
# I1208 17:05:53.342617 25663 solver.cpp:429]     Test net output #0: accuracy = 0.768
# I1208 17:05:53.342628 25663 solver.cpp:429]     Test net output #1: ip5 = 4.89711
# I1208 17:05:53.342629 25663 solver.cpp:429]     Test net output #2: ip5 = -3.29939
# I1208 17:05:53.342631 25663 solver.cpp:429]     Test net output #3: ip5 = 4.89335
# I1208 17:05:53.342633 25663 solver.cpp:429]     Test net output #4: ip5 = -3.31097
# I1208 17:05:53.342635 25663 solver.cpp:429]     Test net output #5: ip5 = 4.06469
# I1208 17:05:53.342638 25663 solver.cpp:429]     Test net output #6: ip5 = -2.73857
# I1208 17:05:53.342639 25663 solver.cpp:429]     Test net output #7: ip5 = 4.69617
# I1208 17:05:53.342640 25663 solver.cpp:429]     Test net output #8: ip5 = -3.16511
# I1208 17:05:53.342643 25663 solver.cpp:429]     Test net output #9: ip5 = 4.5725
# I1208 17:05:53.342643 25663 solver.cpp:429]     Test net output #10: ip5 = -3.06764
# I1208 17:05:53.342645 25663 solver.cpp:429]     Test net output #11: ip5 = 4.62368
# I1208 17:05:53.342646 25663 solver.cpp:429]     Test net output #12: ip5 = -3.13852
# I1208 17:05:53.342648 25663 solver.cpp:429]     Test net output #13: ip5 = 4.92631
# I1208 17:05:53.342650 25663 solver.cpp:429]     Test net output #14: ip5 = -3.30556
# I1208 17:05:53.342651 25663 solver.cpp:429]     Test net output #15: ip5 = 4.31474
# I1208 17:05:53.342653 25663 solver.cpp:429]     Test net output #16: ip5 = -2.9217
# I1208 17:05:53.342655 25663 solver.cpp:429]     Test net output #17: ip5 = 4.69894
# I1208 17:05:53.342656 25663 solver.cpp:429]     Test net output #18: ip5 = -3.19056
# I1208 17:05:53.342658 25663 solver.cpp:429]     Test net output #19: ip5 = 4.51599
# I1208 17:05:53.342659 25663 solver.cpp:429]     Test net output #20: ip5 = -2.98718
# I1208 17:05:53.342664 25663 solver.cpp:429]     Test net output #21: loss = 0.595596 (* 1 = 0.595596 loss)
# I1208 17:05:53.342689 25663 solver.cpp:242] Iteration 400 (25000 iter/s, 0.004s/100 iter), loss = 0.696254
# I1208 17:05:53.342692 25663 solver.cpp:261]     Train net output #0: accuracy = 0.8
# I1208 17:05:53.342694 25663 solver.cpp:261]     Train net output #1: ip5 = 1.59228
# I1208 17:05:53.342706 25663 solver.cpp:261]     Train net output #2: ip5 = -0.928162
# I1208 17:05:53.342708 25663 solver.cpp:261]     Train net output #3: ip5 = 0.82391
# I1208 17:05:53.342710 25663 solver.cpp:261]     Train net output #4: ip5 = -0.588034
# I1208 17:05:53.342711 25663 solver.cpp:261]     Train net output #5: ip5 = 3.27808
# I1208 17:05:53.342713 25663 solver.cpp:261]     Train net output #6: ip5 = -2.05159
# I1208 17:05:53.342715 25663 solver.cpp:261]     Train net output #7: ip5 = 3.08492
# I1208 17:05:53.342716 25663 solver.cpp:261]     Train net output #8: ip5 = -1.93738
# I1208 17:05:53.342718 25663 solver.cpp:261]     Train net output #9: ip5 = 3.7535
# I1208 17:05:53.342720 25663 solver.cpp:261]     Train net output #10: ip5 = -2.42287
# I1208 17:05:53.342721 25663 solver.cpp:261]     Train net output #11: ip5 = 6.20361
# I1208 17:05:53.342722 25663 solver.cpp:261]     Train net output #12: ip5 = -4.09397
# I1208 17:05:53.342725 25663 solver.cpp:261]     Train net output #13: ip5 = 5.27608
# I1208 17:05:53.342726 25663 solver.cpp:261]     Train net output #14: ip5 = -3.3471
# I1208 17:05:53.342727 25663 solver.cpp:261]     Train net output #15: ip5 = 0.903895
# I1208 17:05:53.342730 25663 solver.cpp:261]     Train net output #16: ip5 = -0.488924
# I1208 17:05:53.342730 25663 solver.cpp:261]     Train net output #17: ip5 = 4.84373
# I1208 17:05:53.342732 25663 solver.cpp:261]     Train net output #18: ip5 = -3.01017
# I1208 17:05:53.342735 25663 solver.cpp:261]     Train net output #19: ip5 = 1.62425
# I1208 17:05:53.342736 25663 solver.cpp:261]     Train net output #20: ip5 = -1.09137
# I1208 17:05:53.342738 25663 solver.cpp:261]     Train net output #21: loss = 0.696254 (* 1 = 0.696254 loss)
# I1208 17:05:53.342741 25663 sgd_solver.cpp:106] Iteration 400, lr = 0.001
# I1208 17:05:53.345072 25663 solver.cpp:362] Iteration 500, Testing net (#0)
# I1208 17:05:53.347688 25663 solver.cpp:429]     Test net output #0: accuracy = 0.78
# I1208 17:05:53.347700 25663 solver.cpp:429]     Test net output #1: ip5 = 5.54286
# I1208 17:05:53.347703 25663 solver.cpp:429]     Test net output #2: ip5 = -3.73487
# I1208 17:05:53.347705 25663 solver.cpp:429]     Test net output #3: ip5 = 5.58268
# I1208 17:05:53.347707 25663 solver.cpp:429]     Test net output #4: ip5 = -3.78421
# I1208 17:05:53.347708 25663 solver.cpp:429]     Test net output #5: ip5 = 4.61981
# I1208 17:05:53.347709 25663 solver.cpp:429]     Test net output #6: ip5 = -3.1127
# I1208 17:05:53.347712 25663 solver.cpp:429]     Test net output #7: ip5 = 5.31741
# I1208 17:05:53.347713 25663 solver.cpp:429]     Test net output #8: ip5 = -3.59107
# I1208 17:05:53.347714 25663 solver.cpp:429]     Test net output #9: ip5 = 5.20663
# I1208 17:05:53.347717 25663 solver.cpp:429]     Test net output #10: ip5 = -3.49563
# I1208 17:05:53.347718 25663 solver.cpp:429]     Test net output #11: ip5 = 5.27887
# I1208 17:05:53.347719 25663 solver.cpp:429]     Test net output #12: ip5 = -3.58593
# I1208 17:05:53.347721 25663 solver.cpp:429]     Test net output #13: ip5 = 5.58877
# I1208 17:05:53.347723 25663 solver.cpp:429]     Test net output #14: ip5 = -3.75116
# I1208 17:05:53.347724 25663 solver.cpp:429]     Test net output #15: ip5 = 4.88657
# I1208 17:05:53.347726 25663 solver.cpp:429]     Test net output #16: ip5 = -3.30352
# I1208 17:05:53.347728 25663 solver.cpp:429]     Test net output #17: ip5 = 5.34634
# I1208 17:05:53.347729 25663 solver.cpp:429]     Test net output #18: ip5 = -3.63572
# I1208 17:05:53.347731 25663 solver.cpp:429]     Test net output #19: ip5 = 5.14267
# I1208 17:05:53.347733 25663 solver.cpp:429]     Test net output #20: ip5 = -3.40549
# I1208 17:05:53.347738 25663 solver.cpp:429]     Test net output #21: loss = 0.561925 (* 1 = 0.561925 loss)
# I1208 17:05:53.347765 25663 solver.cpp:242] Iteration 500 (20000 iter/s, 0.005s/100 iter), loss = 0.680892
# I1208 17:05:53.347771 25663 solver.cpp:261]     Train net output #0: accuracy = 0.8
# I1208 17:05:53.347774 25663 solver.cpp:261]     Train net output #1: ip5 = 2.48975
# I1208 17:05:53.347775 25663 solver.cpp:261]     Train net output #2: ip5 = -1.72962
# I1208 17:05:53.347789 25663 solver.cpp:261]     Train net output #3: ip5 = 3.75134
# I1208 17:05:53.347790 25663 solver.cpp:261]     Train net output #4: ip5 = -2.50679
# I1208 17:05:53.347792 25663 solver.cpp:261]     Train net output #5: ip5 = 4.87385
# I1208 17:05:53.347793 25663 solver.cpp:261]     Train net output #6: ip5 = -3.83269
# I1208 17:05:53.347795 25663 solver.cpp:261]     Train net output #7: ip5 = 4.67186
# I1208 17:05:53.347797 25663 solver.cpp:261]     Train net output #8: ip5 = -3.22803
# I1208 17:05:53.347798 25663 solver.cpp:261]     Train net output #9: ip5 = 9.45279
# I1208 17:05:53.347800 25663 solver.cpp:261]     Train net output #10: ip5 = -6.81918
# I1208 17:05:53.347801 25663 solver.cpp:261]     Train net output #11: ip5 = 2.75597
# I1208 17:05:53.347803 25663 solver.cpp:261]     Train net output #12: ip5 = -1.77169
# I1208 17:05:53.347805 25663 solver.cpp:261]     Train net output #13: ip5 = 3.61627
# I1208 17:05:53.347806 25663 solver.cpp:261]     Train net output #14: ip5 = -2.55293
# I1208 17:05:53.347808 25663 solver.cpp:261]     Train net output #15: ip5 = 3.35872
# I1208 17:05:53.347810 25663 solver.cpp:261]     Train net output #16: ip5 = -1.79026
# I1208 17:05:53.347811 25663 solver.cpp:261]     Train net output #17: ip5 = 1.89295
# I1208 17:05:53.347813 25663 solver.cpp:261]     Train net output #18: ip5 = -1.15058
# I1208 17:05:53.347815 25663 solver.cpp:261]     Train net output #19: ip5 = 9.1116
# I1208 17:05:53.347816 25663 solver.cpp:261]     Train net output #20: ip5 = -6.19664
# I1208 17:05:53.347820 25663 solver.cpp:261]     Train net output #21: loss = 0.680892 (* 1 = 0.680892 loss)
# I1208 17:05:53.347821 25663 sgd_solver.cpp:106] Iteration 500, lr = 0.001
# I1208 17:05:53.349869 25663 solver.cpp:362] Iteration 600, Testing net (#0)
# I1208 17:05:53.352404 25663 solver.cpp:429]     Test net output #0: accuracy = 0.784
# I1208 17:05:53.352409 25663 solver.cpp:429]     Test net output #1: ip5 = 5.96781
# I1208 17:05:53.352411 25663 solver.cpp:429]     Test net output #2: ip5 = -4.12867
# I1208 17:05:53.352413 25663 solver.cpp:429]     Test net output #3: ip5 = 6.05166
# I1208 17:05:53.352416 25663 solver.cpp:429]     Test net output #4: ip5 = -4.23459
# I1208 17:05:53.352416 25663 solver.cpp:429]     Test net output #5: ip5 = 4.97715
# I1208 17:05:53.352418 25663 solver.cpp:429]     Test net output #6: ip5 = -3.45782
# I1208 17:05:53.352419 25663 solver.cpp:429]     Test net output #7: ip5 = 5.70577
# I1208 17:05:53.352421 25663 solver.cpp:429]     Test net output #8: ip5 = -3.96262
# I1208 17:05:53.352423 25663 solver.cpp:429]     Test net output #9: ip5 = 5.63903
# I1208 17:05:53.352424 25663 solver.cpp:429]     Test net output #10: ip5 = -3.90134
# I1208 17:05:53.352427 25663 solver.cpp:429]     Test net output #11: ip5 = 5.70175
# I1208 17:05:53.352427 25663 solver.cpp:429]     Test net output #12: ip5 = -3.99862
# ...
# I1208 17:05:53.794386 25663 solver.cpp:261]     Train net output #5: ip5 = 12.105
# I1208 17:05:53.794387 25663 solver.cpp:261]     Train net output #6: ip5 = -5.56548
# I1208 17:05:53.794389 25663 solver.cpp:261]     Train net output #7: ip5 = -0.385308
# I1208 17:05:53.794390 25663 solver.cpp:261]     Train net output #8: ip5 = -3.02309
# I1208 17:05:53.794392 25663 solver.cpp:261]     Train net output #9: ip5 = 28.5273
# I1208 17:05:53.794394 25663 solver.cpp:261]     Train net output #10: ip5 = -32.3321
# I1208 17:05:53.794396 25663 solver.cpp:261]     Train net output #11: ip5 = 11.5895
# I1208 17:05:53.794399 25663 solver.cpp:261]     Train net output #12: ip5 = -3.24763
# I1208 17:05:53.794400 25663 solver.cpp:261]     Train net output #13: ip5 = 1.55939
# I1208 17:05:53.794401 25663 solver.cpp:261]     Train net output #14: ip5 = -4.96238
# I1208 17:05:53.794404 25663 solver.cpp:261]     Train net output #15: ip5 = 1.28166
# I1208 17:05:53.794404 25663 solver.cpp:261]     Train net output #16: ip5 = -0.804198
# I1208 17:05:53.794406 25663 solver.cpp:261]     Train net output #17: ip5 = 11.9501
# I1208 17:05:53.794409 25663 solver.cpp:261]     Train net output #18: ip5 = -13.0792
# I1208 17:05:53.794410 25663 solver.cpp:261]     Train net output #19: ip5 = 4.12101
# I1208 17:05:53.794411 25663 solver.cpp:261]     Train net output #20: ip5 = -2.256
# I1208 17:05:53.794414 25663 solver.cpp:261]     Train net output #21: loss = 0.138678 (* 1 = 0.138678 loss)
# I1208 17:05:53.794417 25663 sgd_solver.cpp:106] Iteration 9600, lr = 0.0001
# I1208 17:05:53.796371 25663 solver.cpp:362] Iteration 9700, Testing net (#0)
# I1208 17:05:53.798887 25663 solver.cpp:429]     Test net output #0: accuracy = 0.816
# I1208 17:05:53.798892 25663 solver.cpp:429]     Test net output #1: ip5 = 8.21734
# I1208 17:05:53.798895 25663 solver.cpp:429]     Test net output #2: ip5 = -5.76822
# I1208 17:05:53.798897 25663 solver.cpp:429]     Test net output #3: ip5 = 9.82955
# I1208 17:05:53.798898 25663 solver.cpp:429]     Test net output #4: ip5 = -6.78994
# I1208 17:05:53.798907 25663 solver.cpp:429]     Test net output #5: ip5 = 10.2472
# I1208 17:05:53.798910 25663 solver.cpp:429]     Test net output #6: ip5 = -7.21206
# I1208 17:05:53.798912 25663 solver.cpp:429]     Test net output #7: ip5 = 8.38624
# I1208 17:05:53.798913 25663 solver.cpp:429]     Test net output #8: ip5 = -5.47968
# I1208 17:05:53.798915 25663 solver.cpp:429]     Test net output #9: ip5 = 10.7713
# I1208 17:05:53.798918 25663 solver.cpp:429]     Test net output #10: ip5 = -8.78261
# I1208 17:05:53.798918 25663 solver.cpp:429]     Test net output #11: ip5 = 9.3514
# I1208 17:05:53.798920 25663 solver.cpp:429]     Test net output #12: ip5 = -6.64079
# I1208 17:05:53.798923 25663 solver.cpp:429]     Test net output #13: ip5 = 9.78911
# I1208 17:05:53.798923 25663 solver.cpp:429]     Test net output #14: ip5 = -6.45028
# I1208 17:05:53.798925 25663 solver.cpp:429]     Test net output #15: ip5 = 8.81531
# I1208 17:05:53.798928 25663 solver.cpp:429]     Test net output #16: ip5 = -5.77641
# I1208 17:05:53.798928 25663 solver.cpp:429]     Test net output #17: ip5 = 10.4259
# I1208 17:05:53.798930 25663 solver.cpp:429]     Test net output #18: ip5 = -6.71111
# I1208 17:05:53.798933 25663 solver.cpp:429]     Test net output #19: ip5 = 10.6129
# I1208 17:05:53.798933 25663 solver.cpp:429]     Test net output #20: ip5 = -5.54056
# I1208 17:05:53.798938 25663 solver.cpp:429]     Test net output #21: loss = 0.705361 (* 1 = 0.705361 loss)
# I1208 17:05:53.798957 25663 solver.cpp:242] Iteration 9700 (25000 iter/s, 0.004s/100 iter), loss = 0.16767
# I1208 17:05:53.798961 25663 solver.cpp:261]     Train net output #0: accuracy = 0.9
# I1208 17:05:53.798964 25663 solver.cpp:261]     Train net output #1: ip5 = 5.96555
# I1208 17:05:53.798965 25663 solver.cpp:261]     Train net output #2: ip5 = -7.51142
# I1208 17:05:53.798966 25663 solver.cpp:261]     Train net output #3: ip5 = 13.3085
# I1208 17:05:53.798969 25663 solver.cpp:261]     Train net output #4: ip5 = -2.87984
# I1208 17:05:53.798970 25663 solver.cpp:261]     Train net output #5: ip5 = 18.8454
# I1208 17:05:53.798972 25663 solver.cpp:261]     Train net output #6: ip5 = -6.15759
# I1208 17:05:53.798974 25663 solver.cpp:261]     Train net output #7: ip5 = 1.61406
# I1208 17:05:53.798975 25663 solver.cpp:261]     Train net output #8: ip5 = -0.31391
# I1208 17:05:53.798976 25663 solver.cpp:261]     Train net output #9: ip5 = 4.73545
# I1208 17:05:53.798979 25663 solver.cpp:261]     Train net output #10: ip5 = -3.13963
# I1208 17:05:53.798980 25663 solver.cpp:261]     Train net output #11: ip5 = 6.75035
# I1208 17:05:53.798981 25663 solver.cpp:261]     Train net output #12: ip5 = -9.06369
# I1208 17:05:53.798984 25663 solver.cpp:261]     Train net output #13: ip5 = 12.7952
# I1208 17:05:53.798985 25663 solver.cpp:261]     Train net output #14: ip5 = -6.20915
# I1208 17:05:53.798986 25663 solver.cpp:261]     Train net output #15: ip5 = 11.7206
# I1208 17:05:53.798988 25663 solver.cpp:261]     Train net output #16: ip5 = -3.43852
# I1208 17:05:53.798990 25663 solver.cpp:261]     Train net output #17: ip5 = 20.6126
# I1208 17:05:53.798992 25663 solver.cpp:261]     Train net output #18: ip5 = -6.59692
# I1208 17:05:53.798993 25663 solver.cpp:261]     Train net output #19: ip5 = 5.86577
# I1208 17:05:53.798995 25663 solver.cpp:261]     Train net output #20: ip5 = -5.23177
# I1208 17:05:53.798997 25663 solver.cpp:261]     Train net output #21: loss = 0.16767 (* 1 = 0.16767 loss)
# I1208 17:05:53.799000 25663 sgd_solver.cpp:106] Iteration 9700, lr = 0.0001
# I1208 17:05:53.800954 25663 solver.cpp:362] Iteration 9800, Testing net (#0)
# I1208 17:05:53.803467 25663 solver.cpp:429]     Test net output #0: accuracy = 0.82
# I1208 17:05:53.803472 25663 solver.cpp:429]     Test net output #1: ip5 = 8.21643
# I1208 17:05:53.803474 25663 solver.cpp:429]     Test net output #2: ip5 = -5.7561
# I1208 17:05:53.803477 25663 solver.cpp:429]     Test net output #3: ip5 = 9.81903
# I1208 17:05:53.803478 25663 solver.cpp:429]     Test net output #4: ip5 = -6.78105
# I1208 17:05:53.803479 25663 solver.cpp:429]     Test net output #5: ip5 = 10.2372
# I1208 17:05:53.803488 25663 solver.cpp:429]     Test net output #6: ip5 = -7.20443
# I1208 17:05:53.803489 25663 solver.cpp:429]     Test net output #7: ip5 = 8.37849
# I1208 17:05:53.803491 25663 solver.cpp:429]     Test net output #8: ip5 = -5.47285
# I1208 17:05:53.803493 25663 solver.cpp:429]     Test net output #9: ip5 = 10.7666
# I1208 17:05:53.803494 25663 solver.cpp:429]     Test net output #10: ip5 = -8.77809
# I1208 17:05:53.803496 25663 solver.cpp:429]     Test net output #11: ip5 = 9.34813
# I1208 17:05:53.803498 25663 solver.cpp:429]     Test net output #12: ip5 = -6.63937
# I1208 17:05:53.803499 25663 solver.cpp:429]     Test net output #13: ip5 = 9.77923
# I1208 17:05:53.803501 25663 solver.cpp:429]     Test net output #14: ip5 = -6.43601
# I1208 17:05:53.803503 25663 solver.cpp:429]     Test net output #15: ip5 = 8.81172
# I1208 17:05:53.803504 25663 solver.cpp:429]     Test net output #16: ip5 = -5.76753
# I1208 17:05:53.803506 25663 solver.cpp:429]     Test net output #17: ip5 = 10.4151
# I1208 17:05:53.803508 25663 solver.cpp:429]     Test net output #18: ip5 = -6.69976
# I1208 17:05:53.803510 25663 solver.cpp:429]     Test net output #19: ip5 = 10.6116
# I1208 17:05:53.803511 25663 solver.cpp:429]     Test net output #20: ip5 = -5.53626
# I1208 17:05:53.803514 25663 solver.cpp:429]     Test net output #21: loss = 0.704628 (* 1 = 0.704628 loss)
# I1208 17:05:53.803534 25663 solver.cpp:242] Iteration 9800 (25000 iter/s, 0.004s/100 iter), loss = 0.0711176
# I1208 17:05:53.803539 25663 solver.cpp:261]     Train net output #0: accuracy = 1
# I1208 17:05:53.803540 25663 solver.cpp:261]     Train net output #1: ip5 = 15.0854
# I1208 17:05:53.803542 25663 solver.cpp:261]     Train net output #2: ip5 = -17.5339
# I1208 17:05:53.803544 25663 solver.cpp:261]     Train net output #3: ip5 = 9.20561
# I1208 17:05:53.803546 25663 solver.cpp:261]     Train net output #4: ip5 = -6.22902
# I1208 17:05:53.803547 25663 solver.cpp:261]     Train net output #5: ip5 = 8.96959
# I1208 17:05:53.803550 25663 solver.cpp:261]     Train net output #6: ip5 = -3.25932
# I1208 17:05:53.803551 25663 solver.cpp:261]     Train net output #7: ip5 = 21.6248
# I1208 17:05:53.803553 25663 solver.cpp:261]     Train net output #8: ip5 = -6.96749
# I1208 17:05:53.803555 25663 solver.cpp:261]     Train net output #9: ip5 = 3.31542
# I1208 17:05:53.803556 25663 solver.cpp:261]     Train net output #10: ip5 = -3.67628
# I1208 17:05:53.803558 25663 solver.cpp:261]     Train net output #11: ip5 = 3.80484
# I1208 17:05:53.803560 25663 solver.cpp:261]     Train net output #12: ip5 = -1.00063
# I1208 17:05:53.803561 25663 solver.cpp:261]     Train net output #13: ip5 = 9.44974
# I1208 17:05:53.803562 25663 solver.cpp:261]     Train net output #14: ip5 = -7.43857
# I1208 17:05:53.803565 25663 solver.cpp:261]     Train net output #15: ip5 = 15.7779
# I1208 17:05:53.803566 25663 solver.cpp:261]     Train net output #16: ip5 = -5.92984
# I1208 17:05:53.803568 25663 solver.cpp:261]     Train net output #17: ip5 = 6.17356
# I1208 17:05:53.803570 25663 solver.cpp:261]     Train net output #18: ip5 = -2.19351
# I1208 17:05:53.803571 25663 solver.cpp:261]     Train net output #19: ip5 = 26.3601
# I1208 17:05:53.803573 25663 solver.cpp:261]     Train net output #20: ip5 = -24.9693
# I1208 17:05:53.803575 25663 solver.cpp:261]     Train net output #21: loss = 0.0711172 (* 1 = 0.0711172 loss)
# I1208 17:05:53.803577 25663 sgd_solver.cpp:106] Iteration 9800, lr = 0.0001
# I1208 17:05:53.805586 25663 solver.cpp:362] Iteration 9900, Testing net (#0)
# I1208 17:05:53.808104 25663 solver.cpp:429]     Test net output #0: accuracy = 0.82
# I1208 17:05:53.808111 25663 solver.cpp:429]     Test net output #1: ip5 = 8.22775
# I1208 17:05:53.808114 25663 solver.cpp:429]     Test net output #2: ip5 = -5.7571
# I1208 17:05:53.808115 25663 solver.cpp:429]     Test net output #3: ip5 = 9.8329
# I1208 17:05:53.808116 25663 solver.cpp:429]     Test net output #4: ip5 = -6.78031
# I1208 17:05:53.808118 25663 solver.cpp:429]     Test net output #5: ip5 = 10.2463
# I1208 17:05:53.808120 25663 solver.cpp:429]     Test net output #6: ip5 = -7.20125
# I1208 17:05:53.808137 25663 solver.cpp:429]     Test net output #7: ip5 = 8.38715
# I1208 17:05:53.808140 25663 solver.cpp:429]     Test net output #8: ip5 = -5.46858
# I1208 17:05:53.808141 25663 solver.cpp:429]     Test net output #9: ip5 = 10.7784
# I1208 17:05:53.808143 25663 solver.cpp:429]     Test net output #10: ip5 = -8.77688
# I1208 17:05:53.808145 25663 solver.cpp:429]     Test net output #11: ip5 = 9.35754
# I1208 17:05:53.808147 25663 solver.cpp:429]     Test net output #12: ip5 = -6.63584
# I1208 17:05:53.808148 25663 solver.cpp:429]     Test net output #13: ip5 = 9.78786
# I1208 17:05:53.808151 25663 solver.cpp:429]     Test net output #14: ip5 = -6.43958
# I1208 17:05:53.808152 25663 solver.cpp:429]     Test net output #15: ip5 = 8.8269
# I1208 17:05:53.808153 25663 solver.cpp:429]     Test net output #16: ip5 = -5.76815
# I1208 17:05:53.808156 25663 solver.cpp:429]     Test net output #17: ip5 = 10.4252
# I1208 17:05:53.808157 25663 solver.cpp:429]     Test net output #18: ip5 = -6.70071
# I1208 17:05:53.808159 25663 solver.cpp:429]     Test net output #19: ip5 = 10.6213
# I1208 17:05:53.808161 25663 solver.cpp:429]     Test net output #20: ip5 = -5.53613
# I1208 17:05:53.808164 25663 solver.cpp:429]     Test net output #21: loss = 0.705535 (* 1 = 0.705535 loss)
# I1208 17:05:53.808588 25663 solver.cpp:242] Iteration 9900 (20000 iter/s, 0.005s/100 iter), loss = 0.0811559
# I1208 17:05:53.808599 25663 solver.cpp:261]     Train net output #0: accuracy = 1
# I1208 17:05:53.808601 25663 solver.cpp:261]     Train net output #1: ip5 = 6.68035
# I1208 17:05:53.808604 25663 solver.cpp:261]     Train net output #2: ip5 = -2.63475
# I1208 17:05:53.808605 25663 solver.cpp:261]     Train net output #3: ip5 = 15.4012
# I1208 17:05:53.808606 25663 solver.cpp:261]     Train net output #4: ip5 = -6.69296
# I1208 17:05:53.808609 25663 solver.cpp:261]     Train net output #5: ip5 = 1.57344
# I1208 17:05:53.808610 25663 solver.cpp:261]     Train net output #6: ip5 = -0.920935
# I1208 17:05:53.808612 25663 solver.cpp:261]     Train net output #7: ip5 = 15.0857
# I1208 17:05:53.808614 25663 solver.cpp:261]     Train net output #8: ip5 = -20.7167
# I1208 17:05:53.808616 25663 solver.cpp:261]     Train net output #9: ip5 = 6.8726
# I1208 17:05:53.808617 25663 solver.cpp:261]     Train net output #10: ip5 = -14.6393
# I1208 17:05:53.808619 25663 solver.cpp:261]     Train net output #11: ip5 = 13.4114
# I1208 17:05:53.808621 25663 solver.cpp:261]     Train net output #12: ip5 = -3.58887
# I1208 17:05:53.808624 25663 solver.cpp:261]     Train net output #13: ip5 = 4.11009
# I1208 17:05:53.808624 25663 solver.cpp:261]     Train net output #14: ip5 = -4.43561
# I1208 17:05:53.808626 25663 solver.cpp:261]     Train net output #15: ip5 = 9.54183
# I1208 17:05:53.808629 25663 solver.cpp:261]     Train net output #16: ip5 = -5.87241
# I1208 17:05:53.808629 25663 solver.cpp:261]     Train net output #17: ip5 = 9.54276
# I1208 17:05:53.808631 25663 solver.cpp:261]     Train net output #18: ip5 = -8.88129
# I1208 17:05:53.808634 25663 solver.cpp:261]     Train net output #19: ip5 = 3.82834
# I1208 17:05:53.808634 25663 solver.cpp:261]     Train net output #20: ip5 = -1.50986
# I1208 17:05:53.808639 25663 solver.cpp:261]     Train net output #21: loss = 0.0811555 (* 1 = 0.0811555 loss)
# I1208 17:05:53.808641 25663 sgd_solver.cpp:106] Iteration 9900, lr = 0.0001
# I1208 17:05:53.810771 25663 solver.cpp:479] Snapshotting to binary proto file DeepLearning/hdf5_classification/data/train_iter_10000.caffemodel
# I1208 17:05:53.810950 25663 sgd_solver.cpp:273] Snapshotting solver state to binary proto file DeepLearning/hdf5_classification/data/train_iter_10000.solverstate
# I1208 17:05:53.811067 25663 solver.cpp:342] Iteration 10000, loss = 0.00436006
# I1208 17:05:53.811074 25663 solver.cpp:362] Iteration 10000, Testing net (#0)
# I1208 17:05:53.813585 25663 solver.cpp:429]     Test net output #0: accuracy = 0.824
# I1208 17:05:53.813588 25663 solver.cpp:429]     Test net output #1: ip5 = 8.24029
# I1208 17:05:53.813591 25663 solver.cpp:429]     Test net output #2: ip5 = -5.75927
# I1208 17:05:53.813592 25663 solver.cpp:429]     Test net output #3: ip5 = 9.8502
# I1208 17:05:53.813602 25663 solver.cpp:429]     Test net output #4: ip5 = -6.77502
# I1208 17:05:53.813604 25663 solver.cpp:429]     Test net output #5: ip5 = 10.2573
# I1208 17:05:53.813607 25663 solver.cpp:429]     Test net output #6: ip5 = -7.19524
# I1208 17:05:53.813608 25663 solver.cpp:429]     Test net output #7: ip5 = 8.40553
# I1208 17:05:53.813611 25663 solver.cpp:429]     Test net output #8: ip5 = -5.46816
# I1208 17:05:53.813611 25663 solver.cpp:429]     Test net output #9: ip5 = 10.7963
# I1208 17:05:53.813613 25663 solver.cpp:429]     Test net output #10: ip5 = -8.78378
# I1208 17:05:53.813616 25663 solver.cpp:429]     Test net output #11: ip5 = 9.36861
# I1208 17:05:53.813617 25663 solver.cpp:429]     Test net output #12: ip5 = -6.63437
# I1208 17:05:53.813618 25663 solver.cpp:429]     Test net output #13: ip5 = 9.80312
# I1208 17:05:53.813621 25663 solver.cpp:429]     Test net output #14: ip5 = -6.44555
# I1208 17:05:53.813622 25663 solver.cpp:429]     Test net output #15: ip5 = 8.83894
# I1208 17:05:53.813623 25663 solver.cpp:429]     Test net output #16: ip5 = -5.76275
# I1208 17:05:53.813626 25663 solver.cpp:429]     Test net output #17: ip5 = 10.441
# I1208 17:05:53.813627 25663 solver.cpp:429]     Test net output #18: ip5 = -6.69132
# I1208 17:05:53.813628 25663 solver.cpp:429]     Test net output #19: ip5 = 10.6361
# I1208 17:05:53.813632 25663 solver.cpp:429]     Test net output #20: ip5 = -5.53229
# I1208 17:05:53.813633 25663 solver.cpp:429]     Test net output #21: loss = 0.706995 (* 1 = 0.706995 loss)
# I1208 17:05:53.813635 25663 solver.cpp:347] Optimization Done.
# I1208 17:05:53.813637 25663 caffe.cpp:234] Optimization Done.

# %%
# !python /home/met/caffe-nv/tools/extra/parse_log.py lenet_train.log .

# %%
train_log = pd.read_csv("./lenet_train.log.train")
test_log = pd.read_csv("./lenet_train.log.test")
_, ax1 = plt.subplots(figsize=(15, 8))
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(train_log["NumIters"], train_log["loss"], alpha=0.4)
ax1.plot(test_log["NumIters"], test_log["loss"], 'g')
ax2.plot(test_log["NumIters"], test_log["accuracy"], 'r')
ax3.plot(train_log["NumIters"], train_log["accuracy"], 'b')

#ax3.plot(train_log["NumIters"], train_log["LearningRate"], 'b')

ax1.axis([0, 10000, 0, 1])
ax2.axis([0, 10000, 0, 1])
ax3.axis([0, 10000, 0, 1])

ax1.set_xlabel('iteration')
ax1.set_ylabel('train loss')
ax2.set_ylabel('test accuracy')

# %% [markdown]
# ## Ready for the submission?
#
# Let's try a prediction! In order to do it, you just need to initialize `caffe.Net` with the prototxt and the trained model.

# %%
net = caffe.Net ('DeepLearning/hdf5_classification/nonlinear_auto_submission.prototxt',
                 'DeepLearning/hdf5_classification/data/train_iter_10000.caffemodel',
                caffe.TEST)

# %% [markdown]
# Finally, you call the `forward()` method for each sample.

# %%
labels = []
for i in xrange(900):
    pred = net.forward()
    labels.append(net.blobs['ip3'].data[...].argmax(axis=1))

# %% [markdown]
# * How the output looks like?
# * What does the `.argmax()`?
# * Try to reshape the `labels` in order to have a vector 1x9000 (Recall numpy Lab)

# %%
y_pred = np.array(labels).reshape(9000)

# %%
with open('submission.csv', 'wb') as csvfile:
    for i in xrange(9000):
        csvfile.write("{0},".format(int(y_pred[i])))

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
